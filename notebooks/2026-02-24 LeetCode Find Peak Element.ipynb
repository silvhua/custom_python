# %% [markdown]
# # Find Peak Element
# * [LeetCode link](https://leetcode.com/problems/find-peak-element/)
# * [NeetCode]()
#
# A peak element is an element that is strictly greater than its neighbors.
#
# Given a 0-indexed integer array `nums`, find a peak element, and return its index. If the array contains multiple peaks, return the index to any of the peaks.
#
# You may imagine that `nums[-1] = nums[n] = -∞`. In other words, an element is always considered to be strictly greater than a neighbor that is outside the array.
#
# You must write an algorithm that runs in `O(log n)` time.
#
# Example 1:
# ```
# Input: nums = [1,2,3,1]
# Output: 2
# ```
# Explanation: 3 is a peak element and your function should return the index number 2.
# Example 2:
# ```
# Input: nums = [1,2,1,3,5,6,4]
# Output: 5
# ```
# Explanation: Your function can return either index number 1 where the peak element is 2, or index number 5 where the peak element is 6.
#
#
# Constraints:
#
# * `1 <= nums.length <= 1000`
# * $ -2^{31} $ <= `nums[i]` <= $ 2^{31} $ - 1
# * `nums[i] != nums[i + 1]` for all valid i.
#
# ## Skeleton code
# ```python
# class Solution(object):
#     def findPeakElement(self, nums):
#         """
#         :type nums: List[int]
#         :rtype: int
#         """
# ```

# %% [markdown]
# ## Iteration 1
# * Time: $ O() $
# * Space: $ O() $

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def findPeakElement(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        self.nums = nums
        self.indices = [x for x in range(len(nums))]
        peak = None
        while len(self.indices) > 0 and peak == None:
            L, R = 0, len(self.indices)
            guess_index = self.indices[self.getMidPointIndex(L, R)]
            peak = self.isPeak(guess_index)
        return peak

    def getMidPointIndex(self, L, R):
        mid = (R - L) // 2 + L
        return mid
    
    def isPeak(self, guess_index):
        self.indices.remove(guess_index)
        if guess_index == len(self.nums) - 1 or guess_index == 0:
            return guess_index
        guess_value = self.nums[guess_index]
        left_of_guess_index = guess_index - 1
        right_of_guess_index = guess_index + 1
        guess_left_neighbor = self.nums[left_of_guess_index]
        guess_right_neighbor= self.nums[right_of_guess_index]
        if guess_value > guess_left_neighbor and guess_value > guess_right_neighbor:
            if left_of_guess_index in self.indices:
                self.indices.remove(left_of_guess_index)
            if right_of_guess_index in self.indices:
                self.indices.remove(right_of_guess_index)
            return guess_index
        else:
            return None

cases = {
    1: {
        "nums": [1,2,3,1],
        "Output": 2
    },
    2: {
        "nums": [1,2,1,3,5,6,4],
        "Output": 5
    },
    3: {
        "nums": [2, 1]
        "Output": 0
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    nums= case["nums"]
    Output = case["Output"]


    result = solution.findPeakElement(nums)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# nums: [1, 2, 3, 1]	Output: 2
# Result: 2
# Answer is correct: True
#
#
# *** Case 2 ***
# nums: [1, 2, 1, 3, 5, 6, 4]	Output: 5
# Result: 5
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ## iteration 2

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def findPeakElement(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        self.nums = nums
        self.indices = [x for x in range(len(nums))]
        peak = None
        while len(self.indices) > 0 and peak == None:
            L, R = 0, len(self.indices)
            guess_index = self.indices[self.getMidPointIndex(L, R)]
            peak = self.isPeak(guess_index)
        return peak

    def getMidPointIndex(self, L, R):
        mid = (R - L) // 2 + L
        return mid
    
    def isPeak(self, guess_index):
        self.indices.remove(guess_index)
        guess_value = self.nums[guess_index]
        left_of_guess_index = guess_index - 1
        right_of_guess_index = guess_index + 1
        # print(guess_index, left_of_guess_index, right_of_guess_index, self.nums)
        if guess_index == len(self.nums) - 1 and guess_value > self.nums[guess_index - 1]:
            return guess_index
        if guess_index == 0 and guess_value > self.nums[guess_index + 1]:
            return guess_index
        guess_left_neighbor = self.nums[left_of_guess_index]
        guess_right_neighbor = self.nums[right_of_guess_index] if right_of_guess_index < len(self.nums) else self.nums[0]
        if guess_value > guess_left_neighbor and guess_value > guess_right_neighbor:
            if left_of_guess_index in self.indices:
                self.indices.remove(left_of_guess_index)
            if right_of_guess_index in self.indices:
                self.indices.remove(right_of_guess_index)
            return guess_index
        else:
            return None

cases = {
    1: {
        "nums": [1,2,3,1],
        "Output": 2
    },
    2: {
        "nums": [1,2,1,3,5,6,4],
        "Output": 5
    },
    3: {
        "nums": [2, 1],
        "Output": 0
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    nums= case["nums"]
    Output = case["Output"]


    result = solution.findPeakElement(nums)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# nums: [1, 2, 3, 1]	Output: 2
# Result: 2
# Answer is correct: True
#
#
# *** Case 2 ***
# nums: [1, 2, 1, 3, 5, 6, 4]	Output: 5
# Result: 5
# Answer is correct: True
#
#
# *** Case 3 ***
# nums: [2, 1]	Output: 0
# Result: 0
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ### 2.1

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def findPeakElement(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        self.nums = nums
        self.indices = [x for x in range(len(nums))]
        peak = None
        while len(self.indices) > 0 and peak == None:
            L, R = 0, len(self.indices)
            guess_index = self.indices[self.getMidPointIndex(L, R)]
            peak = self.isPeak(guess_index)
        return peak

    def getMidPointIndex(self, L, R):
        mid = (R - L) // 2 + L
        return mid
    
    def isPeak(self, guess_index):
        self.indices.remove(guess_index)
        guess_value = self.nums[guess_index]
        left_of_guess_index = guess_index - 1 if guess_index > 0 else 1
        right_of_guess_index = guess_index + 1 if guess_index < len(self.nums) - 1 else 0
        if guess_index == len(self.nums) - 1 and guess_value > self.nums[left_of_guess_index]:
            return guess_index
        if guess_index == 0 and guess_value > self.nums[right_of_guess_index]:
            return guess_index
        guess_left_neighbor = self.nums[left_of_guess_index]
        guess_right_neighbor = self.nums[right_of_guess_index]
        if guess_value > guess_left_neighbor and guess_value > guess_right_neighbor:
            if left_of_guess_index in self.indices:
                self.indices.remove(left_of_guess_index)
            if right_of_guess_index in self.indices:
                self.indices.remove(right_of_guess_index)
            return guess_index
        else:
            return None

cases = {
    1: {
        "nums": [1,2,3,1],
        "Output": 2
    },
    2: {
        "nums": [1,2,1,3,5,6,4],
        "Output": 5
    },
    3: {
        "nums": [2, 1],
        "Output": 0
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    nums= case["nums"]
    Output = case["Output"]


    result = solution.findPeakElement(nums)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# nums: [1, 2, 3, 1]	Output: 2
# Result: 2
# Answer is correct: True
#
#
# *** Case 2 ***
# nums: [1, 2, 1, 3, 5, 6, 4]	Output: 5
# Result: 5
# Answer is correct: True
#
#
# *** Case 3 ***
# nums: [2, 1]	Output: 0
# Result: 0
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ### 2.2 [accepted]
# * Runtime 11 ms Beats 0.95%
# * Memory 12.64 MB Beats 19.36%

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def findPeakElement(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        if len(nums) == 1:
            return 0
        self.nums = nums
        self.indices = [x for x in range(len(nums))]
        peak = None
        while len(self.indices) > 0 and peak == None:
            L, R = 0, len(self.indices)
            guess_index = self.indices[self.getMidPointIndex(L, R)]
            peak = self.isPeak(guess_index)
        return peak

    def getMidPointIndex(self, L, R):
        mid = (R - L) // 2 + L
        return mid
    
    def isPeak(self, guess_index):
        self.indices.remove(guess_index)
        guess_value = self.nums[guess_index]
        left_of_guess_index = guess_index - 1 if guess_index > 0 else 1
        right_of_guess_index = guess_index + 1 if guess_index < len(self.nums) - 1 else 0
        if guess_index == len(self.nums) - 1 and guess_value > self.nums[left_of_guess_index]:
            return guess_index
        if guess_index == 0 and guess_value > self.nums[right_of_guess_index]:
            return guess_index
        guess_left_neighbor = self.nums[left_of_guess_index]
        guess_right_neighbor = self.nums[right_of_guess_index]
        if guess_value > guess_left_neighbor and guess_value > guess_right_neighbor:
            if left_of_guess_index in self.indices:
                self.indices.remove(left_of_guess_index)
            if right_of_guess_index in self.indices:
                self.indices.remove(right_of_guess_index)
            return guess_index
        else:
            return None

cases = {
    1: {
        "nums": [1,2,3,1],
        "Output": 2
    },
    2: {
        "nums": [1,2,1,3,5,6,4],
        "Output": 5
    },
    3: {
        "nums": [2, 1],
        "Output": 0
    },
    4: {
        "nums": [1],
        "Output": 0
    },
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    nums= case["nums"]
    Output = case["Output"]


    result = solution.findPeakElement(nums)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")

# %% [markdown]
# # *End of Page*
