# %% [markdown]
# # Leaf-Similar Trees
# * [LeetCode link](https://leetcode.com/problems/leaf-similar-trees/description/)
# * [NeetCode](https://neetcode.io/solutions/leaf-similar-trees)
#
# Consider all the leaves of a binary tree, from left to right order, the values of those leaves form a leaf value sequence.
#
#
# For example, in the given tree above, the leaf value sequence is (6, 7, 4, 9, 8).
#
# Two binary trees are considered leaf-similar if their leaf value sequence is the same.
#
# Return `true `if and only if the two given trees with head nodes `root1` and `root2` are leaf-similar.
#
#
#
# Example 1:
# ```
# Input: root1 = [3,5,1,6,2,9,8,null,null,7,4], root2 = [3,5,1,6,7,4,2,null,null,null,null,null,null,9,8]
# Output: true
# ```
# Example 2:
# ```
# Input: root1 = [1,2,3], root2 = [1,3,2]
# Output: false
# ```
#
# Constraints:
#
# * The number of nodes in each tree will be in the range [1, 200].
# * Both of the given trees will have values in the range [0, 200].
#
# ## Skeleton code
# ```python
# # Definition for a binary tree node.
# # class TreeNode:
# #     def __init__(self, val=0, left=None, right=None):
# #         self.val = val
# #         self.left = left
# #         self.right = right
# class Solution:
#     def leafSimilar(self, root1: Optional[TreeNode], root2: Optional[TreeNode]) -> bool:
# ```

# %% [markdown]
# ## Build the tree

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    # def leafSimilar(self, root1, root2) -> bool:

    def preorder_length(self, root, length):
        if not root:
            return length
        length += 1
        left_length = self.preorder_length(root.left, length)
        right_length = self.preorder_length(root.right, length)
        return max(right_length, left_length)

    def buildTree(self, nodes):
        # Treat the tree as a heap
        self.nodes = [None] + nodes
        self.tree = self.createNode(1)
        return self.tree


    def createNode(self, index):
        if index >= len(self.nodes):
            return None
        left_child_index = index * 2
        right_child_index = index * 2 + 1
        val = self.nodes[index]
        # print(f"\tval: {val}\tindex: {index}\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        node = TreeNode(
            val,
            self.createNode(left_child_index),
            self.createNode(right_child_index)
            )
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            nodes_list.append(None)
            return
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")

    def addToNodesList(self, node, nodes_list):
        if not node:
            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)
        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)


cases = {
    1: {
        "root1": [3,5,1,6,2,9,8,None,None,7,4], 
        "root2": [3,5,1,6,7,4,2,None,None,None,None,None,None,9,8],
        "Output": True
    },
    2: {
        "root1": [1,2,3], 
        "root2": [1,3,2],
        "Output": False
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []
solution = Solution()
solution2 = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    root1 = case["root1"]
    root2 = case["root2"]
    Output = case["Output"]

    tree1 = solution.buildTree(root1)
    solution.printNodes(tree1, [])

    tree2 = solution2.buildTree(root2)
    solution2.printNodes(tree2, [])

    # result = solution.leafSimilar(tree1, tree2)
    # correct_for_case = result == Output
    # print(f"Result: {result}")
    # correct.append(correct_for_case)
    # print(f"Answer is correct: {correct_for_case}\n\n")
# print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# root1: [3, 5, 1, 6, 2, 9, 8, None, None, 7, 4]	root2: [3, 5, 1, 6, 7, 4, 2, None, None, None, None, None, None, 9, 8]	Output: True
# Tree nodes: [3, 5, 1, 6, 2, None, None, 7, 4, 9, 8]
# Tree nodes: [3, 5, 1, 6, 7, None, None, None, None, 4, 2, None, None, 9, 8]
# *** Case 2 ***
# root1: [1, 2, 3]	root2: [1, 3, 2]	Output: False
# Tree nodes: [1, 2, 3]
# Tree nodes: [1, 3, 2]

# %% [markdown]
# ## Iteration 1
# * Time: $ O() $
# * Space: $ O() $

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    # def leafSimilar(self, root1, root2) -> bool:

    def preorder_length(self, root, length):
        if not root:
            return length
        length += 1
        left_length = self.preorder_length(root.left, length)
        right_length = self.preorder_length(root.right, length)
        return max(right_length, left_length)

    def preorder_isLeaf(self, root, leaf_values = []):
        if not root:
            return False
        has_left_child = self.preorder_isLeaf(root.left, leaf_values)
        has_right_child = self.preorder_isLeaf(root.right, leaf_values)
        if has_left_child == False and has_right_child == False:
            leaf_values.append(root.val)
        return leaf_values

    def buildTree(self, nodes):
        # Treat the tree as a heap
        self.nodes = [None] + nodes
        self.tree = self.createNode(1)
        return self.tree


    def createNode(self, index):
        if index >= len(self.nodes):
            return None
        left_child_index = index * 2
        right_child_index = index * 2 + 1
        val = self.nodes[index]
        # print(f"\tval: {val}\tindex: {index}\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        node = TreeNode(
            val,
            self.createNode(left_child_index),
            self.createNode(right_child_index)
            )
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            nodes_list.append(None)
            return
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")

    def addToNodesList(self, node, nodes_list):
        if not node:
            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)
        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)


cases = {
    1: {
        "root1": [3,5,1,6,2,9,8,None,None,7,4], 
        "root2": [3,5,1,6,7,4,2,None,None,None,None,None,None,9,8],
        "Output": True
    },
    2: {
        "root1": [1,2,3], 
        "root2": [1,3,2],
        "Output": False
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []
solution = Solution()
solution2 = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"\n*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    
    root1 = case["root1"]
    root2 = case["root2"]
    Output = case["Output"]

    tree1 = solution.buildTree(root1)
    solution.printNodes(tree1, [])
    tree1_leave_nodes = solution.preorder_isLeaf(tree1, [])
    print(f"\tTree 1 leaf nodes: {[node for node in tree1_leave_nodes]}")

    tree2 = solution2.buildTree(root2)
    solution2.printNodes(tree2, [])

    # result = solution.leafSimilar(tree1, tree2)
    # correct_for_case = result == Output
    # print(f"Result: {result}")
    # correct.append(correct_for_case)
    # print(f"Answer is correct: {correct_for_case}\n\n")
# print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# root1: [3, 5, 1, 6, 2, 9, 8, None, None, 7, 4]	root2: [3, 5, 1, 6, 7, 4, 2, None, None, None, None, None, None, 9, 8]	Output: True	Tree nodes: [3, 5, 1, 6, 2, None, None, 7, 4, 9, 8]
# 	Tree 1 leaf nodes: [None, None, 7, 4, 9, 8]
# Tree nodes: [3, 5, 1, 6, 7, None, None, None, None, 4, 2, None, None, 9, 8]
#
# *** Case 2 ***
# root1: [1, 2, 3]	root2: [1, 3, 2]	Output: False	Tree nodes: [1, 2, 3]
# 	Tree 1 leaf nodes: [2, 3]
# Tree nodes: [1, 3, 2]

# %% [markdown]
# ### 1.1

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def leafSimilar(self, root1, root2) -> bool:
        self.tree1_leaves = self.preorder_isLeaf(root1, [])
        # self.tree2_leaves = self.preorder_isLeaf(root2, [])
        # return self.tree1_leaves == self.tree2_leaves
        return False

    def preorder_length(self, root, length):
        if not root:
            return length
        length += 1
        left_length = self.preorder_length(root.left, length)
        right_length = self.preorder_length(root.right, length)
        return max(right_length, left_length)

    def preorder_isLeaf(self, root, leaf_values = []):
        if not root:
            # print(f"\tisLeaf for None")
            return False
        # print(f"\tisLeaf for {root.val}")
        has_left_child = root.left and root.left.val != None
        has_right_child = root.right and root.right.val != None
        if not has_left_child and not has_right_child:
            # print(f"\t\tNo children")
            leaf_values.append(root.val)
            return leaf_values
        # print(f"\t\tchildren: {root.left.val}, {root.right.val}")
        if has_left_child:
            leaf_values = self.preorder_isLeaf(root.left)
        if has_right_child:
            leaf_values = self.preorder_isLeaf(root.right)
        return leaf_values

    def buildTree(self, nodes):
        # Treat the tree as a heap
        self.nodes = [None] + nodes
        self.tree = self.createNode(1)
        return self.tree


    def createNode(self, index):
        if index >= len(self.nodes):
            return None
        left_child_index = index * 2
        right_child_index = index * 2 + 1
        val = self.nodes[index]
        # print(f"\tval: {val}\tindex: {index}\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        node = TreeNode(
            val,
            self.createNode(left_child_index),
            self.createNode(right_child_index)
            )
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            nodes_list.append(None)
            return
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")

    def addToNodesList(self, node, nodes_list):
        if not node:
            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)
        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)


cases = {
    # 1: {
    #     "root1": [3,5,1,6,2,9,8,None,None,7,4], 
    #     "root2": [3,5,1,6,7,4,2,None,None,None,None,None,None,9,8],
    #     "Output": True
    # },
    2: {
        "root1": [1,2,3], 
        "root2": [1,3,2],
        "Output": False
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []

for case_number in cases:
    solution = Solution()
    solution2 = Solution()
    case = cases[case_number]
    print(f"\n*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    
    root1 = case["root1"]
    root2 = case["root2"]
    Output = case["Output"]

    tree1 = solution.buildTree(root1)
    solution.printNodes(tree1, [])
    # tree1_leave_nodes = solution.preorder_isLeaf(tree1, [])
    # print(f"\tTree 1 leaf nodes: {[node for node in tree1_leave_nodes]}")

    tree2 = solution2.buildTree(root2)
    solution2.printNodes(tree2, [])
    # tree2_leave_nodes = solution2.preorder_isLeaf(tree2, [])
    # print(f"\tTree 2 leaf nodes: {[node for node in tree2_leave_nodes]}")

    result = solution.leafSimilar(tree1, tree2)
    # print(f"\ttree 1 leaf nodes: {solution.tree1_leaves}\ttree 2 leaf nodes: {solution.tree2_leaves}")
    print(f"\ttree 1 leaf nodes: {solution.tree1_leaves}")
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 2 ***
# root1: [1, 2, 3]	root2: [1, 3, 2]	Output: False	Tree nodes: [1, 2, 3]
# Tree nodes: [1, 3, 2]
# 	tree 1 leaf nodes: [2, 3]
# Result: False
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %%
solution.tree1_leaves
# Out:
# [6, 7, 4, 9, 8, 6, 7, 4, 9, 8]

# %%
[1, 2, 3] == [1, 2, 3]
# Out:
# True

# %%
[1, 2, 4] == [1, 2, 3]
# Out:
# False

# %% [markdown]
# ### 1.2 accepted
# * Time: $ O(N1+N2) $
# * Space: $ O(H1+H2) $
# * Runtime 1 ms Beats 12.67%
# * Memory 19.56 MB Beats 8.52%

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def leafSimilar(self, root1, root2) -> bool:
        self.tree1_leaves = self.preorder_isLeaf(root1, [])
        self.tree2_leaves = self.preorder_isLeaf(root2, [])
        return self.tree1_leaves == self.tree2_leaves

    def preorder_isLeaf(self, root, leaf_values = []):
        if not root:
            # print(f"\tisLeaf for None")
            return False
        # print(f"\tisLeaf for {root.val}")
        has_left_child = root.left and root.left.val != None
        has_right_child = root.right and root.right.val != None
        if not has_left_child and not has_right_child:
            # print(f"\t\tNo children")
            leaf_values.append(root.val)
            return leaf_values
        # print(f"\t\tchildren: {root.left.val}, {root.right.val}")
        if has_left_child:
            leaf_values = self.preorder_isLeaf(root.left, leaf_values)
        if has_right_child:
            leaf_values = self.preorder_isLeaf(root.right, leaf_values)
        return leaf_values

    def preorder_length(self, root, length):
        if not root:
            return length
        length += 1
        left_length = self.preorder_length(root.left, length)
        right_length = self.preorder_length(root.right, length)
        return max(right_length, left_length)

    def buildTree(self, nodes):
        # Treat the tree as a heap
        self.nodes = [None] + nodes
        self.tree = self.createNode(1)
        return self.tree


    def createNode(self, index):
        if index >= len(self.nodes):
            return None
        left_child_index = index * 2
        right_child_index = index * 2 + 1
        val = self.nodes[index]
        # print(f"\tval: {val}\tindex: {index}\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        node = TreeNode(
            val,
            self.createNode(left_child_index),
            self.createNode(right_child_index)
            )
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            nodes_list.append(None)
            return
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")

    def addToNodesList(self, node, nodes_list):
        if not node:
            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)
        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)


cases = {
    1: {
        "root1": [3,5,1,6,2,9,8,None,None,7,4], 
        "root2": [3,5,1,6,7,4,2,None,None,None,None,None,None,9,8],
        "Output": True
    },
    2: {
        "root1": [1,2,3], 
        "root2": [1,3,2],
        "Output": False
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []

for case_number in cases:
    solution = Solution()
    solution2 = Solution()
    case = cases[case_number]
    print(f"\n*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    
    root1 = case["root1"]
    root2 = case["root2"]
    Output = case["Output"]

    tree1 = solution.buildTree(root1)
    solution.printNodes(tree1, [])
    # tree1_leave_nodes = solution.preorder_isLeaf(tree1, [])
    # print(f"\tTree 1 leaf nodes: {[node for node in tree1_leave_nodes]}")

    tree2 = solution2.buildTree(root2)
    solution2.printNodes(tree2, [])
    # tree2_leave_nodes = solution2.preorder_isLeaf(tree2, [])
    # print(f"\tTree 2 leaf nodes: {[node for node in tree2_leave_nodes]}")

    result = solution.leafSimilar(tree1, tree2)
    print(f"\ttree 1 leaf nodes: {solution.tree1_leaves}\ttree 2 leaf nodes: {solution.tree2_leaves}")
    # print(f"\ttree 1 leaf nodes: {solution.tree1_leaves}")
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# root1: [3, 5, 1, 6, 2, 9, 8, None, None, 7, 4]	root2: [3, 5, 1, 6, 7, 4, 2, None, None, None, None, None, None, 9, 8]	Output: True	Tree nodes: [3, 5, 1, 6, 2, None, None, 7, 4, 9, 8]
# Tree nodes: [3, 5, 1, 6, 7, None, None, None, None, 4, 2, None, None, 9, 8]
# 	tree 1 leaf nodes: [6, 7, 4, 9, 8]	tree 2 leaf nodes: [6, 7, 4, 9, 8]
# Result: True
# Answer is correct: True
#
#
#
# *** Case 2 ***
# root1: [1, 2, 3]	root2: [1, 3, 2]	Output: False	Tree nodes: [1, 2, 3]
# Tree nodes: [1, 3, 2]
# 	tree 1 leaf nodes: [2, 3]	tree 2 leaf nodes: [3, 2]
# Result: False
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ## test Neetcode solutions
# 2. DFS (Space Optimized)

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    # def leafSimilar(self, root1, root2) -> bool:
    #     self.tree1_leaves = self.preorder_isLeaf(root1, [])
    #     self.tree2_leaves = self.preorder_isLeaf(root2, [])
    #     return self.tree1_leaves == self.tree2_leaves
    def leafSimilar(self, root1, root2) -> bool:
        def dfs(root, leaf):
            if not root:
                return
            if not root.left and not root.right:
                leaf.append(root.val)
                return
            dfs(root.left, leaf)
            dfs(root.right, leaf)

        leaf1 = []
        dfs(root1, leaf1)

        def dfs1(root, leaf):
            print(f"root val: {root.val}")
            print(f"\tleaf: {leaf}")
            if not root:
                return True
            if not root.left and not root.right:
                if not leaf:
                    return False
                print(f"\tleaf.pop: {leaf[-1]}")
                return leaf.pop() == root.val
            return dfs1(root.right, leaf) and dfs1(root.left, leaf)

        return dfs1(root2, leaf1) and not leaf1

    def preorder_isLeaf(self, root, leaf_values = []):
        if not root:
            # print(f"\tisLeaf for None")
            return False
        # print(f"\tisLeaf for {root.val}")
        has_left_child = root.left and root.left.val != None
        has_right_child = root.right and root.right.val != None
        if not has_left_child and not has_right_child:
            # print(f"\t\tNo children")
            leaf_values.append(root.val)
            return leaf_values
        # print(f"\t\tchildren: {root.left.val}, {root.right.val}")
        if has_left_child:
            leaf_values = self.preorder_isLeaf(root.left, leaf_values)
        if has_right_child:
            leaf_values = self.preorder_isLeaf(root.right, leaf_values)
        return leaf_values

    def preorder_length(self, root, length):
        if not root:
            return length
        length += 1
        left_length = self.preorder_length(root.left, length)
        right_length = self.preorder_length(root.right, length)
        return max(right_length, left_length)

    def buildTree(self, nodes):
        # Treat the tree as a heap
        self.nodes = [None] + nodes
        self.tree = self.createNode(1)
        return self.tree


    def createNode(self, index):
        if index >= len(self.nodes):
            return None
        left_child_index = index * 2
        right_child_index = index * 2 + 1
        val = self.nodes[index]
        # print(f"\tval: {val}\tindex: {index}\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        node = TreeNode(
            val,
            self.createNode(left_child_index),
            self.createNode(right_child_index)
            )
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            nodes_list.append(None)
            return
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")

    def addToNodesList(self, node, nodes_list):
        if not node:
            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)
        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)


cases = {
    # 1: {
    #     "root1": [3,5,1,6,2,9,8,None,None,7,4], 
    #     "root2": [3,5,1,6,7,4,2,None,None,None,None,None,None,9,8],
    #     "Output": True
    # },
    2: {
        "root1": [1,2,3], 
        "root2": [1,3,2],
        "Output": False
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []

for case_number in cases:
    solution = Solution()
    solution2 = Solution()
    case = cases[case_number]
    print(f"\n*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    
    root1 = case["root1"]
    root2 = case["root2"]
    Output = case["Output"]

    tree1 = solution.buildTree(root1)
    solution.printNodes(tree1, [])
    # tree1_leave_nodes = solution.preorder_isLeaf(tree1, [])
    # print(f"\tTree 1 leaf nodes: {[node for node in tree1_leave_nodes]}")

    tree2 = solution2.buildTree(root2)
    solution2.printNodes(tree2, [])
    # tree2_leave_nodes = solution2.preorder_isLeaf(tree2, [])
    # print(f"\tTree 2 leaf nodes: {[node for node in tree2_leave_nodes]}")

    result = solution.leafSimilar(tree1, tree2)
    
    # print(f"\ttree 1 leaf nodes: {solution.tree1_leaves}")
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 2 ***
# root1: [1, 2, 3]	root2: [1, 3, 2]	Output: False	Tree nodes: [1, 2, 3]
# Tree nodes: [1, 3, 2]
# root val: 1
# 	leaf: [2, 3]
# root val: 2
# 	leaf: [2, 3]
# 	leaf.pop: 3
# Result: False
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %%
[3, 2].pop()
# Out:
# 2

# %% [markdown]
# # *End of Page*
