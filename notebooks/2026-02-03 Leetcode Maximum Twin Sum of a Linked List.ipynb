# %% [markdown]
# # Maximum Twin Sum of a Linked List
# * [LeetCode link](https://leetcode.com/problems/maximum-twin-sum-of-a-linked-list/)
# * [NeetCode link]()
#
# In a linked list of size `n`, where `n` is even, the `ith` node (0-indexed) of the linked list is known as the twin of the `(n-1-i)th` node, if `0 <= i <= (n / 2) - 1`.
#
# For example, if `n = 4`, then node `0` is the twin of node `3`, and node `1` is the twin of node `2`. These are the only nodes with twins for `n = 4`.
# The twin sum is defined as the sum of a node and its twin.
#
# Given the `head` of a linked list with even length, return the maximum twin sum of the linked list.
#
#
#
# Example 1:
# ```
#
# Input: head = [5,4,2,1]
# Output: 6
# ```
# Explanation:
# Nodes 0 and 1 are the twins of nodes 3 and 2, respectively. All have twin sum = 6.
# There are no other nodes with twins in the linked list.
# Thus, the maximum twin sum of the linked list is 6.
# Example 2:
# ```
#
# Input: head = [4,2,2,3]
# Output: 7
# ```
# Explanation:
# The nodes with twins present in this linked list are:
# - Node 0 is the twin of node 3 having a twin sum of 4 + 3 = 7.
# - Node 1 is the twin of node 2 having a twin sum of 2 + 2 = 4.
# Thus, the maximum twin sum of the linked list is max(7, 4) = 7.
# Example 3:
# ```
#
# Input: head = [1,100000]
# Output: 100001
# ```
# Explanation:
# There is only one node with a twin in the linked list having twin sum of 1 + 100000 = 100001.
#
#
# Constraints:
#
# * The number of nodes in the list is an even integer in the range [2, $ 10^5 $].
# * 1 <= `Node.val` <= $ 10^5 $
#
# ## Skeleton code
# ```python
# # Definition for singly-linked list.
# # class ListNode:
# #     def __init__(self, val=0, next=None):
# #         self.val = val
# #         self.next = next
# class Solution:
#     def pairSum(self, head: Optional[ListNode]) -> int:
# ```

# %% [markdown]
# ## Iteration 1 Accepted
# * Time: $ O(N) $
# * Space: $ O(N) $
#
# Used the hints in LeetCode
# * Runtime: 67 ms Beats 69.83%
# * Memory: 63.50 MB Beats 6.69%

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def pairSum(self, head):
        # Keep track of the nodes of the linked list
        self.list_nodes = []
        current = head
        while current:
            self.list_nodes.append(current)
            current = current.next
        left, right = 0, len(self.list_nodes) - 1
        twin_sums = []
        while left < right:
            left_value = self.list_nodes[left].val
            right_value = self.list_nodes[right].val
            twin_sums.append(left_value + right_value)
            left += 1
            right -= 1
        return max(twin_sums)
        
    
    def createLinkedList(self, node_values):
        self.nodes = {}
        if len(node_values) > 0:
            self.nodes[len(node_values) - 1] = ListNode(node_values[-1])
            for i in range(len(node_values) - 2, -1, -1):
                val = node_values[i]
                next_val = node_values[i + 1]
                self.nodes[i] = ListNode(val, self.nodes[i + 1])
            head = self.nodes[0]
        else:
            head = ListNode(None)
        return head


cases = {
    1: {
        "head": [5,4,2,1],
        "Output": 6
    },
    2: {
        "head": [4,2,2,3],
        "Output": 7
    },
    3: {
        "head": [1,100000],
        "Output": 100001
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    node_values = case["head"]
    head = solution.createLinkedList(node_values)
        
    Output = case["Output"]
    result = solution.pairSum(head)

    # Print linked list to check that it is created correctly
    print(f"\tNode values: ")
    for node in solution.list_nodes:
        print(f"\t\tvalue: {node.val}\tnext value: {node.next.val if node.next else 'None'}")
        
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# head: [5, 4, 2, 1]	Output: 6
# 	Node values:
# 		value: 5	next value: 4
# 		value: 4	next value: 2
# 		value: 2	next value: 1
# 		value: 1	next value: None
# Result: 6
# Answer is correct: True
#
#
# *** Case 2 ***
# head: [4, 2, 2, 3]	Output: 7
# 	Node values:
# 		value: 4	next value: 2
# 		value: 2	next value: 2
# 		value: 2	next value: 3
# 		value: 3	next value: None
# Result: 7
# Answer is correct: True
#
#
# *** Case 3 ***
# head: [1, 100000]	Output: 100001
# 	Node values:
# 		value: 1	next value: 100000
# 		value: 100000	next value: None
# Result: 100001
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ## Iteration 2 Try to reduce memory usage
# * Runtime 61 ms Beats 79.17%
# * Memory 62.66 MB Beats 13.79%

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def pairSum(self, head):
        # Keep track of the nodes of the linked list
        self.list_nodes = []
        current = head
        while current:
            self.list_nodes.append(current.val)
            current = current.next
        left, right = 0, len(self.list_nodes) - 1
        twin_sums = []
        while left < right:
            left_value = self.list_nodes[left]
            right_value = self.list_nodes[right]
            twin_sums.append(left_value + right_value)
            left += 1
            right -= 1
        return max(twin_sums)
        
    
    def createLinkedList(self, node_values):
        self.nodes = {}
        if len(node_values) > 0:
            self.nodes[len(node_values) - 1] = ListNode(node_values[-1])
            for i in range(len(node_values) - 2, -1, -1):
                val = node_values[i]
                next_val = node_values[i + 1]
                self.nodes[i] = ListNode(val, self.nodes[i + 1])
            head = self.nodes[0]
        else:
            head = ListNode(None)
        return head


cases = {
    1: {
        "head": [5,4,2,1],
        "Output": 6
    },
    2: {
        "head": [4,2,2,3],
        "Output": 7
    },
    3: {
        "head": [1,100000],
        "Output": 100001
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    node_values = case["head"]
    head = solution.createLinkedList(node_values)
        
    Output = case["Output"]
    result = solution.pairSum(head)
        
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# head: [5, 4, 2, 1]	Output: 6
# Result: 6
# Answer is correct: True
#
#
# *** Case 2 ***
# head: [4, 2, 2, 3]	Output: 7
# Result: 7
# Answer is correct: True
#
#
# *** Case 3 ***
# head: [1, 100000]	Output: 100001
# Result: 100001
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# # *End of Page*
