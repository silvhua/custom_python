# %% [markdown]
# # Number of Recent Calls
# * [LeetCode link](https://leetcode.com/problems/number-of-recent-calls/)
#
# You have a `RecentCounter` class which counts the number of recent requests within a certain time frame.
#
# Implement the `RecentCounter` class:
#
# * `RecentCounter()` Initializes the counter with zero recent requests.
# * `int ping(int t)` Adds a new request at time `t`, where `t` represents some time in milliseconds, and returns the number of requests that has happened in the past `3000` milliseconds (including the new request). Specifically, return the number of requests that have happened in the inclusive range `[t - 3000, t]`.
# It is guaranteed that every call to `ping` uses a strictly larger value of `t` than the previous call.
#
#
#
# Example 1:
# ```
# Input
# ["RecentCounter", "ping", "ping", "ping", "ping"]
# [[], [1], [100], [3001], [3002]]
# Output
# [null, 1, 2, 3, 3]
# ```
# Explanation
# ```
# RecentCounter recentCounter = new RecentCounter();
# recentCounter.ping(1);     // requests = [1], range is [-2999,1], return 1
# recentCounter.ping(100);   // requests = [1, 100], range is [-2900,100], return 2
# recentCounter.ping(3001);  // requests = [1, 100, 3001], range is [1,3001], return 3
# recentCounter.ping(3002);  // requests = [1, 100, 3001, 3002], range is [2,3002], return 3
# ```
#
# ## Skeleton code
# ```python
# class RecentCounter:
#
#     def __init__(self):
#
#
#     def ping(self, t: int) -> int:
#
# # Your RecentCounter object will be instantiated and called as such:
# # obj = RecentCounter()
# # param_1 = obj.ping(t)
# ```

# %% [markdown]
# ## Iteration 1
# * Time: $ O() $
# * Space: $ O() $

# %%
class RecentCounter:

    def __init__(self):
        self.pings = []
        

    def ping(self, t: int) -> int:
        self.pings.append(t)
        t1 = t - 3000
        relevant_pings = [x for x in self.pings if x >= t1]
        print(f"\trelevant pings: {relevant_pings}\tcount: {len(relevant_pings)}")
        return len(relevant_pings)
        


# Your RecentCounter object will be instantiated and called as such:
# obj = RecentCounter()
# param_1 = obj.ping(t)


cases = {
    1: {
        "t": 1,
        "Output": 1
    },
    2: {
        "t": 100,
        "Output": 2
    },
    3: {
        "t": 3001,
        "Output": 3
    },
    4: {
        "t": 3002,
        "Output": 3
    }
}

correct = []
obj = RecentCounter()


for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    t = case["t"]
    Output = case["Output"]
    result = obj.ping(t)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
    print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# t: 1	Output: 1
# 	relevant pings: [1]	count: 1
# Result: 1
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 2 ***
# t: 100	Output: 2
# 	relevant pings: [1, 100]	count: 2
# Result: 2
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 3 ***
# t: 3001	Output: 3
# 	relevant pings: [1, 100, 3001]	count: 3
# Result: 3
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 4 ***
# t: 3002	Output: 3
# 	relevant pings: [100, 3001, 3002]	count: 3
# Result: 3
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ## 1.1 (remove print) Accepted
# * Time: $ O(n) $
# * Space: $ O(n) $
# * Runtime 4288 ms, Beats 6.86%

# %%
class RecentCounter:

    def __init__(self):
        self.pings = []
        

    def ping(self, t: int) -> int:
        self.pings.append(t)
        t1 = t - 3000
        relevant_pings = [x for x in self.pings if x >= t1]
        print(f"\trelevant pings: {relevant_pings}\tcount: {len(relevant_pings)}")
        return len(relevant_pings)
        


# Your RecentCounter object will be instantiated and called as such:
# obj = RecentCounter()
# param_1 = obj.ping(t)


cases = {
    1: {
        "t": 1,
        "Output": 1
    },
    2: {
        "t": 100,
        "Output": 2
    },
    3: {
        "t": 3001,
        "Output": 3
    },
    4: {
        "t": 3002,
        "Output": 3
    }
}

correct = []
obj = RecentCounter()


for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    t = case["t"]
    Output = case["Output"]
    result = obj.ping(t)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
    print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")

# %% [markdown]
# ## Iteration 2

# %%
class RecentCounter:

    def __init__(self):
        self.pings = []
        

    def ping(self, t: int) -> int:
        self.pings.append(t)
        t1 = t - 3000
        first_relevant_ping_index = 0
        for i in range(len(self.pings)):
            if self.pings[i] >= t1:
                first_relevant_ping_index = i
                break
        print(f"\trelevant pings: {self.pings[first_relevant_ping_index:]}\tindex: {first_relevant_ping_index}")
        result = len(self.pings) - first_relevant_ping_index
        return result
        
        


# Your RecentCounter object will be instantiated and called as such:
# obj = RecentCounter()
# param_1 = obj.ping(t)


cases = {
    1: {
        "t": 1,
        "Output": 1
    },
    2: {
        "t": 100,
        "Output": 2
    },
    3: {
        "t": 3001,
        "Output": 3
    },
    4: {
        "t": 3002,
        "Output": 3
    }
}

correct = []
obj = RecentCounter()


for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    t = case["t"]
    Output = case["Output"]
    result = obj.ping(t)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
    print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# t: 1	Output: 1
# 	relevant pings: [1]	index: 0
# Result: 1
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 2 ***
# t: 100	Output: 2
# 	relevant pings: [1, 100]	index: 0
# Result: 2
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 3 ***
# t: 3001	Output: 3
# 	relevant pings: [1, 100, 3001]	index: 0
# Result: 3
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 4 ***
# t: 3002	Output: 3
# 	relevant pings: [100, 3001, 3002]	index: 1
# Result: 3
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ### 2.1 Tried to make it faster, but it was actually slower
# Runtime
# 8245
# ms
# Beats
# 5.00%

# %%
class RecentCounter:

    def __init__(self):
        self.pings = []
        

    def ping(self, t: int) -> int:
        self.pings.append(t)
        t1 = t - 3000
        for i in range(len(self.pings)):
            if self.pings[i] >= t1:
                return len(self.pings) - i
        
        


# Your RecentCounter object will be instantiated and called as such:
# obj = RecentCounter()
# param_1 = obj.ping(t)


cases = {
    1: {
        "t": 1,
        "Output": 1
    },
    2: {
        "t": 100,
        "Output": 2
    },
    3: {
        "t": 3001,
        "Output": 3
    },
    4: {
        "t": 3002,
        "Output": 3
    }
}

correct = []
obj = RecentCounter()


for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    t = case["t"]
    Output = case["Output"]
    result = obj.ping(t)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
    print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# t: 1	Output: 1
# Result: 1
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 2 ***
# t: 100	Output: 2
# Result: 2
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 3 ***
# t: 3001	Output: 3
# Result: 3
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****
# *** Case 4 ***
# t: 3002	Output: 3
# Result: 3
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# # *End of Page*
