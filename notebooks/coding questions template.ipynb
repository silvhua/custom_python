# %% [markdown]
# # Title
# * [NeetCode link]()
# * [LeetCode link]()
#
#
# ## Skeleton code
# ```python
#
# ```

# %% [markdown]
# ## Iteration 1
# * Time: $ O() $
# * Space: $ O() $

# %%
cases = {
    1: {
        "Output": 
    },
    2: {
        "Output": 
    },
    3: {
        "Output": 
    }
}

solution = Solution()

for case in cases:
    print(f"*** Case {case} ***")
    
    Output = cases[case]["Output"]
    result = solution.()
    print(f"Answer is correct: {result == Output}\n\n")

# %% [markdown]
# ## Iteration 2
# * Time: $ O() $
# * Space: $ O() $

# %% [markdown]
# # *End of Page*
