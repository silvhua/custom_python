# %% [markdown]
# # Letter Combinations of a Phone Number
# * [LeetCode link](https://leetcode.com/problems/letter-combinations-of-a-phone-number/)
#
# Given a string containing digits from 2-9 inclusive, return all possible letter combinations that the number could represent. Return the answer in any order.
#
# A mapping of digits to letters (just like on the telephone buttons) is given below. Note that 1 does not map to any letters.
#
# Example 1:
# ```
# Input: digits = "23"
# Output: ["ad","ae","af","bd","be","bf","cd","ce","cf"]
# ```
# Example 2:
# ```
# Input: digits = "2"
# Output: ["a","b","c"]
# ```
#
# Constraints:
#
# * 1 <= `digits.length` <= 4
# * `digits[i]` is a digit in the range `['2', '9']`.
#
# ## Skeleton code
# ```python
# class Solution(object):
#     def letterCombinations(self, digits):
#         """
#         :type digits: str
#         :rtype: List[str]
#         """
# ```

# %% [markdown]
# ## Iteration 1
# * Time: $ O() $
# * Space: $ O() $

# %%
class Solution(object):
    def letterCombinations(self, digits):
        """
        :type digits: str
        :rtype: List[str]
        """
        self.digits_map = {
            "2": "abc",
            "3": "def",
            "4": "ghi",
            "5": "jkl",
            "6": "mno",
            "7": "pqrs",
            "8": "tuv",
            "9": "wxyz"
        }
        self.hash_map = {0: {}}
        for i in range(len(digits)):
            digit = digits[i]
            prefixes_set = self.hash_map[i].values() if self.hash_map[i].values() else [" "]
            print(f"\tprefixes_set for i = {i}: {prefixes_set}")
            for prefixes in prefixes_set:
                print(f"\tprefixes set: {prefixes_set}")
                for prefix in prefixes:
                    print(f"\t\tprefix: {prefix}")
                    self.getLetters(digit, prefix)
        result = []
        for key in self.hash_map[len(digits)]:
            strings_list = self.hash_map[len(digits)][key]
            for item in strings_list:
                result.append(item.strip())
        return result


    def getLetters(self, digit, prefix):
        letters = self.digits_map[digit]
        prefix_length = len(prefix)
        if prefix_length not in self.hash_map:
            self.hash_map[prefix_length] = {}
        print(f"\t\t getLetters key: {prefix_length}")
        self.hash_map[prefix_length][prefix] = [f"{prefix}{letter}" for letter in letters]
        print(f"\thash map: {self.hash_map}")


cases = {
    1: {
        "digits": "23",
        "Output": ["ad","ae","af","bd","be","bf","cd","ce","cf"]
    },
    2: {
        "digits": "2",
        "Output": ["a","b","c"]
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    digits = case["digits"]
    Output = case["Output"]
    result = solution.letterCombinations(digits)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# digits: 23	Output: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# 	prefixes_set for i = 0: [' ']
# 	prefixes set: [' ']
# 		prefix:
# 		 getLetters key: 1
# 	hash map: {0: {}, 1: {' ': [' a', ' b', ' c']}}
# 	prefixes_set for i = 1: dict_values([[' a', ' b', ' c']])
# 	prefixes set: dict_values([[' a', ' b', ' c']])
# 		prefix:  a
# 		 getLetters key: 2
# 	hash map: {0: {}, 1: {' ': [' a', ' b', ' c']}, 2: {' a': [' ad', ' ae', ' af']}}
# 		prefix:  b
# 		 getLetters key: 2
# 	hash map: {0: {}, 1: {' ': [' a', ' b', ' c']}, 2: {' a': [' ad', ' ae', ' af'], ' b': [' bd', ' be', ' bf']}}
# 		prefix:  c
# 		 getLetters key: 2
# 	hash map: {0: {}, 1: {' ': [' a', ' b', ' c']}, 2: {' a': [' ad', ' ae', ' af'], ' b': [' bd', ' be', ' bf'], ' c': [' cd', ' ce', ' cf']}}
# Result: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Answer is correct: True
#
#
# *** Case 2 ***
# digits: 2	Output: ['a', 'b', 'c']
# 	prefixes_set for i = 0: [' ']
# ...

# %% [markdown]
# ### 1.1
# * Time: $ O(N^3) $
# * Space: $ O(3N) $

# %%
class Solution(object):
    def letterCombinations(self, digits):
        """
        :type digits: str
        :rtype: List[str]
        """
        self.digits_map = {
            "2": "abc",
            "3": "def",
            "4": "ghi",
            "5": "jkl",
            "6": "mno",
            "7": "pqrs",
            "8": "tuv",
            "9": "wxyz"
        }
        self.hash_map = {0: {}}
        for i in range(len(digits)):
            digit = digits[i]
            prefixes_set = self.hash_map[i].values() if self.hash_map[i].values() else [" "]
            for prefixes in prefixes_set:
                for prefix in prefixes:
                    self.getLetters(digit, prefix)
        result = []
        for key in self.hash_map[len(digits)]:
            strings_list = self.hash_map[len(digits)][key]
            for item in strings_list:
                result.append(item.strip())
        return result


    def getLetters(self, digit, prefix):
        letters = self.digits_map[digit]
        prefix_length = len(prefix)
        if prefix_length not in self.hash_map:
            self.hash_map[prefix_length] = {}
        self.hash_map[prefix_length][prefix] = [f"{prefix}{letter}" for letter in letters]


cases = {
    1: {
        "digits": "23",
        "Output": ["ad","ae","af","bd","be","bf","cd","ce","cf"]
    },
    2: {
        "digits": "2",
        "Output": ["a","b","c"]
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    digits = case["digits"]
    Output = case["Output"]
    result = solution.letterCombinations(digits)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# digits: 23	Output: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Result: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Answer is correct: True
#
#
# *** Case 2 ***
# digits: 2	Output: ['a', 'b', 'c']
# Result: ['a', 'b', 'c']
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ## Iteration 2
# * Time: $ O(4^N) $
# * Space: $ O(4^N) $

# %%
class Solution(object):
    def letterCombinations(self, digits):
        """
        :type digits: str
        :rtype: List[str]
        """
        self.digits_map = {
            "2": "abc",
            "3": "def",
            "4": "ghi",
            "5": "jkl",
            "6": "mno",
            "7": "pqrs",
            "8": "tuv",
            "9": "wxyz"
        }
        prefixes_set = [" "]
        self.strings = []
        for i in range(len(digits)):
            digit = digits[i]
            prefixes_set = self.getLetters(digit, prefixes_set)
        return prefixes_set


    def getLetters(self, digit, prefixes_set):
        letters = self.digits_map[digit]
        new_prefixes_set = []
        for prefix in prefixes_set:
            for letter in letters:
                new_prefixes_set.append(f"{prefix.strip()}{letter}")
        return new_prefixes_set


cases = {
    1: {
        "digits": "23",
        "Output": ["ad","ae","af","bd","be","bf","cd","ce","cf"]
    },
    2: {
        "digits": "2",
        "Output": ["a","b","c"]
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    digits = case["digits"]
    Output = case["Output"]
    result = solution.letterCombinations(digits)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# digits: 23	Output: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Result: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Answer is correct: True
#
#
# *** Case 2 ***
# digits: 2	Output: ['a', 'b', 'c']
# Result: ['a', 'b', 'c']
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ### 2.1 modified for Leetcode

# %%
class Solution(object):
    def letterCombinations(self, digits):
        """
        :type digits: str
        :rtype: List[str]
        """
        self.digits_map = {
            "2": "abc",
            "3": "def",
            "4": "ghi",
            "5": "jkl",
            "6": "mno",
            "7": "pqrs",
            "8": "tuv",
            "9": "wxyz"
        }
        prefixes_set = [" "]
        self.strings = []
        for i in range(len(digits)):
            digit = digits[i]
            prefixes_set = self.getLetters(digit, prefixes_set)
        return prefixes_set


    def getLetters(self, digit, prefixes_set):
        letters = self.digits_map[digit]
        new_prefixes_set = []
        for prefix in prefixes_set:
            for letter in letters:
                string = prefix.strip() + letter
                new_prefixes_set.append(string)
        return new_prefixes_set


cases = {
    1: {
        "digits": "23",
        "Output": ["ad","ae","af","bd","be","bf","cd","ce","cf"]
    },
    2: {
        "digits": "2",
        "Output": ["a","b","c"]
    },
    # 3: {
    #     "Output": 
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    digits = case["digits"]
    Output = case["Output"]
    result = solution.letterCombinations(digits)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# digits: 23	Output: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Result: ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']
# Answer is correct: True
#
#
# *** Case 2 ***
# digits: 2	Output: ['a', 'b', 'c']
# Result: ['a', 'b', 'c']
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# # *End of Page*
