# %% [markdown]
# # Binary Tree Preorder Traversal
#
# You are given the root of a binary tree, return the preorder traversal of its nodes' values.
#
# * [LeetCode link]()
# * [NeetCode link](https://neetcode.io/problems/binary-tree-preorder-traversal/question)
#
# Example 1:
# ```
# Input: root = [1,2,3,4,5,6,7]
#
# Output: [1,2,4,5,3,6,7]
# ```
# Example 2:
# ```
# Input: root = [1,2,3,null,4,5,null]
#
# Output: [1,2,4,3,5]
# ```
# Example 3:
# ```
# Input: root = []
#
# Output: []
# ```
#
# Constraints:
# * 0 <= number of nodes in the tree <= 100
# * -100 <= Node.val <= 175
#
# Follow up: Recursive solution is trivial, could you do it iteratively?
#
# ## Skeleton code
# ```python
# # Definition for a binary tree node.
# # class TreeNode:
# #     def __init__(self, val=0, left=None, right=None):
# #         self.val = val
# #         self.left = left
# #         self.right = right
# class Solution:
#     def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
# ```

# %% [markdown]
# ## Iteration 1: Submission is correct, but build function is incorrect
# * Time: $ O() $
# * Space: $ O() $

# %%
from typing import Optional, List
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        stack = []
        result = []
        pointer = root
        while pointer:
            # print(f'Pointer val: {pointer.val}')
            if pointer.val:
                result.append(pointer.val)
            if pointer.right:
                stack.append(pointer.right)
            if pointer.left:
                pointer = pointer.left
                print(f'New pointer: {pointer.val}')
            elif len(stack) > 0:
                pointer = stack.pop()
                print(f'New pointer from stack: {pointer.val}')
            else:
                return result
        return result

    def buildTree(self, nodes):
        # Treat the tree as a heap
        nodes = [None] + nodes
        self.tree = self.createNode(1, nodes)
        return self.tree

    def createNode(self, index, nodes):
        if index >= len(nodes):
            # print(f"\tindex exceeded\n\t\tindex: {index}\t# of nodes: {len(nodes)}")
            return None
        left_child_index = index * 2
        
        ## handle case if the node is the right child and its older sibling is None
        if index % 2 == 1 and nodes[index - 1] == None and index > 1:
            print(f"\t** adjusting children indices and nodes list")
            nodes = nodes[index - 1:]
            index = 1
            left_child_index = 2
        right_child_index = left_child_index + 1
        val = nodes[index]
        # print(f"\tcreateNode index: {index}\tvalue: {val}")
        # print(f"\t\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        if val:
            node = TreeNode(
                val,
                self.createNode(left_child_index, nodes),
                self.createNode(right_child_index, nodes)
                )
        else:
            node = TreeNode(val, None, None)
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            return nodes_list
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")
        return nodes_list

    def addToNodesList(self, node, nodes_list, index=1):
        if not node:

            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)

        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)
cases = {
    # 1: {
    #    "root": [1,2,3,4,5,6,7],
    #     "Output": [1,2,4,5,3,6,7]
    # },
    2: {
        "root": [1,2,3,None,4,5,None],
        "Output": [1,2,4,3,5]
    },
    # 3: {
    #     "root": [],
    #     "Output": []
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    root = case["root"]
    Output = case["Output"]
    tree = solution.buildTree(root)

    result = solution.preorderTraversal(tree)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 2 ***
# root: [1, 2, 3, None, 4, 5, None]	Output: [1, 2, 4, 3, 5]
# 	** adjusting children indices and nodes list
# New pointer: 2
# New pointer: None
# New pointer from stack: 4
# New pointer: 5
# New pointer from stack: None
# New pointer from stack: 3
# New pointer: 5
# New pointer from stack: None
# Result: [1, 2, 4, 5, 3, 5]
# Answer is correct: False
#
#
#
# ***** All cases correct: False *****

# %% [markdown]
# # Fix building the tree

# %%
from typing import Optional, List
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        stack = []
        result = []
        pointer = root
        while pointer:
            # print(f'Pointer val: {pointer.val}')
            if pointer.val:
                result.append(pointer.val)
            if pointer.right:
                stack.append(pointer.right)
            if pointer.left:
                pointer = pointer.left
                print(f'New pointer: {pointer.val}')
            elif len(stack) > 0:
                pointer = stack.pop()
                print(f'New pointer from stack: {pointer.val}')
            else:
                return result
        return result

    def buildTree(self, nodes):
        # Treat the tree as a heap
        nodes = [None] + nodes
        self.tree = self.createNode(1, nodes)
        return self.tree

    def createNode(self, index, nodes):
        if index >= len(nodes):
            # print(f"\tindex exceeded\n\t\tindex: {index}\t# of nodes: {len(nodes)}")
            return None
        left_child_index = index * 2
        
        ## handle case if the node is the right child and its older sibling is None
        # if index % 2 == 1 and nodes[index - 1] == None and index > 1:
        #     print(f"\t** adjusting children indices and nodes list")
        #     nodes = nodes[index - 1:]
        #     index = 1
        #     left_child_index = 2
        right_child_index = left_child_index + 1
        val = nodes[index]
        # print(f"\tcreateNode index: {index}\tvalue: {val}")
        # print(f"\t\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        if val:
            node = TreeNode(
                val,
                self.createNode(left_child_index, nodes),
                self.createNode(right_child_index, nodes)
                )
        else:
            node = TreeNode(val, None, None)
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            return nodes_list
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")
        return nodes_list

    def addToNodesList(self, node, nodes_list, index=1):
        if not node:

            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)

        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)
cases = {
    1: {
       "root": [1,2,3,4,5,6,7],
        "Output": [1,2,4,5,3,6,7]
    },
    2: {
        "root": [1,2,3,None,4,5,None],
        "Output": [1,2,4,3,5]
    },
    3: {
        "root": [],
        "Output": []
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    root = case["root"]
    Output = case["Output"]
    tree = solution.buildTree(root)

    result = solution.preorderTraversal(tree)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# root: [1, 2, 3, 4, 5, 6, 7]	Output: [1, 2, 4, 5, 3, 6, 7]
# New pointer: 2
# New pointer: 4
# New pointer from stack: 5
# New pointer from stack: 3
# New pointer: 6
# New pointer from stack: 7
# Result: [1, 2, 4, 5, 3, 6, 7]
# Answer is correct: True
#
#
# *** Case 2 ***
# root: [1, 2, 3, None, 4, 5, None]	Output: [1, 2, 4, 3, 5]
# New pointer: 2
# New pointer: None
# New pointer from stack: 4
# New pointer from stack: 3
# New pointer: 5
# New pointer from stack: None
# Result: [1, 2, 4, 3, 5]
# Answer is correct: True
#
#
# *** Case 3 ***
# root: []	Output: []
# Result: []
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# # *End of Page*
