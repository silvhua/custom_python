# %% [markdown]
# # Minimum Size Subarray Sum
#
# * [LeetCode link]()
# * [NeetCode link](https://neetcode.io/problems/minimum-size-subarray-sum/question?list=neetcode150)
#
# You are given an array of positive integers `nums` and a positive integer `target`, return the minimal length of a subarray whose sum is greater than or equal to target. If there is no such subarray, return `0` instead.
#
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Example 1:
# ```
# Input: target = 10, nums = [2,1,5,1,5,3]
#
# Output: 3
# ```
# Explanation: The subarray [5,1,5] has the minimal length under the problem constraint.
#
# Example 2:
# ```
# Input: target = 5, nums = [1,2,1]
#
# Output: 0
# ```
# Constraints:
#
# * `1 <= nums.length <= 100,000`
# * `1 <= nums[i] <= 10,000`
# * `1 <= target <= 1,000,000,000`
# Follow up: If you have figured out the `O(n)` solution, try coding another solution of which the time complexity is `O(n log(n))`.
#
# ## Skeleton code
# ```python
# class Solution:
#     def minSubArrayLen(self, target: int, nums: List[int]) -> int:
#
# ```

# %% [markdown]
# ## Iteration 1
# * Time: $ O() $
# * Space: $ O() $

# %%
class Solution:
    def minSubArrayLen(self, target: int, nums) -> int:
        L, R = 0, 0
        min_length = 0
        current_sum = nums[L]
        while R + 1 < len(nums):
            R += 1
            current_sum += nums[R]
            print(f"\tIncrementing R to {R}")
            print(f"\t\tNew sum: {current_sum}")
            if current_sum >= target:
                L = R
                current_sum = nums[L]
                print(f"\tSetting L to match R ({L})\n\t\tcurrent sum: {current_sum}")
                current_length = R - L + 1
                min_length = min(current_length, min_length) if min_length > 0 else min_length
        print(f"Min length: {min_length}")

cases = {
    1: {
        "target": 10, 
        "nums": [2,1,5,1,5,3],
        "Output": 3
    },
    # 2: {
    #     "target": 5, 
    #     "nums": [1,2,1],
    #     "Output": 0
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    target = case["target"]
    nums = case ["nums"]
    Output = case["Output"]
    result = solution.minSubArrayLen(target, nums)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# target: 10	nums: [2, 1, 5, 1, 5, 3]	Output: 3
# 	Incrementing R to 1
# 		New sum: 3
# 	Incrementing R to 2
# 		New sum: 8
# 	Incrementing R to 3
# 		New sum: 9
# 	Incrementing R to 4
# 		New sum: 14
# 	Setting L to match R (4)
# 		current sum: 5
# 	Incrementing R to 5
# 		New sum: 8
# Min length: 0
# Result: None
# Answer is correct: False
#
#
#
# ***** All cases correct: False *****

# %% [markdown]
# ## Iteration 2 accepted
# * Time: $ O(N) $
# * Space: $ O(1) $
#
# * Runtime 30ms | Beats 99.94%
# * Memory 10.2 MB | Beats 68.07%

# %%
class Solution:
    def minSubArrayLen(self, target: int, nums) -> int:
        L, sum = 0, 0
        min_length = float("inf")
        for R in range(len(nums)):
            sum += nums[R]
            while sum >= target:
                min_length = min(R - L + 1, min_length)
                sum -= nums[L]
                L += 1
        return min_length if min_length < float("inf") else 0
        

cases = {
    1: {
        "target": 10, 
        "nums": [2,1,5,1,5,3],
        "Output": 3
    },
    2: {
        "target": 5, 
        "nums": [1,2,1],
        "Output": 0
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    target = case["target"]
    nums = case ["nums"]
    Output = case["Output"]
    result = solution.minSubArrayLen(target, nums)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# target: 10	nums: [2, 1, 5, 1, 5, 3]	Output: 3
# Result: 3
# Answer is correct: True
#
#
# *** Case 2 ***
# target: 5	nums: [1, 2, 1]	Output: 0
# Result: 0
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# # *End of Page*
