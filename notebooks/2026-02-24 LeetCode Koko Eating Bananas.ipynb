# %% [markdown]
# # Koko Eating Bananas
# * [LeetCode link](https://leetcode.com/problems/koko-eating-bananas/)
# * [NeetCode]()
#
# Koko loves to eat bananas. There are `n` piles of bananas, the $ i^{th} $ pile has `piles[i]` bananas. The guards have gone and will come back in `h` hours.
#
# Koko can decide her bananas-per-hour eating speed of `k`. Each hour, she chooses some pile of bananas and eats `k` bananas from that pile. If the pile has less than `k` bananas, she eats all of them instead and will not eat any more bananas during this hour.
#
# Koko likes to eat slowly but still wants to finish eating all the bananas before the guards return.
#
# Return the minimum integer `k` such that she can eat all the bananas within `h` hours.
#
# Example 1:
# ```
# Input: piles = [3,6,7,11], h = 8
# Output: 4
# ```
# Example 2:
# ```
# Input: piles = [30,11,23,4,20], h = 5
# Output: 30
# ```
# Example 3:
# ```
# Input: piles = [30,11,23,4,20], h = 6
# Output: 23
# ```
#
# Constraints:
#
# * 1 <= `piles.length` <= $ 10^4 $
# * `piles.length` <= h <= $ 10^9 $
# * 1 <= `piles[i]` <= $ 10^9 $
#
# ## Skeleton code
# ```python
# class Solution(object):
#     def minEatingSpeed(self, piles, h):
#         """
#         :type piles: List[int]
#         :type h: int
#         :rtype: int
#         """
# ```

# %% [markdown]
# ## Iteration 1
# * Time: $ O() $
# * Space: $ O() $

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def minEatingSpeed(self, piles, h):
        """
        :type piles: List[int]
        :type h: int
        :rtype: int
        """
        total_n = sum(piles)
        piles_per_hour = len(piles) / h
        average_n_per_pile = total_n/len(piles)
        min_eating_speed = total_n / h
        print(f"total bananas: {total_n}\tMin speed: {min_eating_speed}\taverage bananas per pile: {average_n_per_pile}\tpiles/hour: {piles_per_hour}")
        if piles_per_hour >= 1:
            result = max(piles)
        elif piles_per_hour > 0.5:
            result = sorted(piles)[-2]
        else:
            result = round((total_n + 1) / h)
        return result
        
    def getMidPointIndex(self, L, R):
        mid = (R - L) / 2 + L
        return mid


cases = {
    1: {
        "piles": [3,6,7,11], 
        "h": 8,
        "Output": 4
    },
    2: {
        "piles": [30,11,23,4,20], 
        "h": 5,
        "Output": 30
    },
    3: {
        "piles": [30,11,23,4,20], 
        "h": 6,
        "Output": 23
    },
    4: {
        "piles": [3,6,7,14], 
        "h": 8,
        "Output": 5
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    piles = case["piles"]
    h = case["h"]
    Output = case["Output"]

    result = solution.minEatingSpeed(piles, h)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# piles: [3, 6, 7, 11]	h: 8	Output: 4
# total bananas: 27	Min speed: 3.375	average bananas per pile: 6.75	piles/hour: 0.5
# Result: 4
# Answer is correct: True
#
#
# *** Case 2 ***
# piles: [30, 11, 23, 4, 20]	h: 5	Output: 30
# total bananas: 88	Min speed: 17.6	average bananas per pile: 17.6	piles/hour: 1.0
# Result: 30
# Answer is correct: True
#
#
# *** Case 3 ***
# piles: [30, 11, 23, 4, 20]	h: 6	Output: 23
# total bananas: 88	Min speed: 14.666666666666666	average bananas per pile: 17.6	piles/hour: 0.8333333333333334
# Result: 23
# Answer is correct: True
#
#
# *** Case 4 ***
# piles: [3, 6, 7, 14]	h: 8	Output: 5
# total bananas: 30	Min speed: 3.75	average bananas per pile: 7.5	piles/hour: 0.5
# Result: 4
# Answer is correct: False
#
#
#
# ***** All cases correct: False *****

# %% [markdown]
# ### Iteration 1.1
# * Time: $ O() $
# * Space: $ O() $

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def minEatingSpeed(self, piles, h):
        """
        :type piles: List[int]
        :type h: int
        :rtype: int
        """
        self.piles = sorted(piles)
        self.h = h
        self.total_n = sum(piles)
        piles_per_hour = len(piles) / h
        average_n_per_pile = self.total_n/len(piles)
        min_eating_speed = self.total_n / h
        print(f"piles: {self.piles}")
        print(f"\ttotal bananas: {self.total_n}\tMin speed: {min_eating_speed}\taverage bananas per pile: {average_n_per_pile}\tpiles/hour: {piles_per_hour}")
        if piles_per_hour >= 1:
            result = self.piles[-1]
        elif piles_per_hour > 0.5:
            result = self.piles[-2]
        else:
            result = round((self.total_n + 1) / h)
        while self.checkSuccess(result) == False:
            result += 1
        return result
        
    def checkSuccess(self, eating_speed):
        eaten = 0
        current_pile = 0
        hour = 1

        # for hour in range(self.h):
        while hour <= self.h and current_pile < len(self.piles):
            print(f"\tcurrent pile: {current_pile}")
            bananas_in_current_pile = self.piles[current_pile]
            while bananas_in_current_pile > 0:
                eaten += min(bananas_in_current_pile, eating_speed)
                bananas_in_current_pile -= eating_speed
                print(f"\t\tbananas remaining in pile {current_pile}: {bananas_in_current_pile}")
                hour += 1
            current_pile += 1
            print(f"\t\tincrementing current pile to: {current_pile}")
        isSuccess = eaten >= self.total_n
        print(f"\tchecking success of rate {eating_speed} resulting in {eaten} eaten: {isSuccess}")
        return isSuccess

cases = {
    1: {
        "piles": [3,6,7,11], 
        "h": 8,
        "Output": 4
    },
    2: {
        "piles": [30,11,23,4,20], 
        "h": 5,
        "Output": 30
    },
    3: {
        "piles": [30,11,23,4,20], 
        "h": 6,
        "Output": 23
    },
    4: {
        "piles": [30,11,23,4,20], 
        "h": 7,
        "Output": 20
    },
    # 5: {
    #     "piles": [3,6,7,14], 
    #     "h": 8,
    #     "Output": 5
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    piles = case["piles"]
    h = case["h"]
    Output = case["Output"]

    result = solution.minEatingSpeed(piles, h)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# piles: [3, 6, 7, 11]	h: 8	Output: 4
# piles: [3, 6, 7, 11]
# 	total bananas: 27	Min speed: 3.375	average bananas per pile: 6.75	piles/hour: 0.5
# 	current pile: 0
# 		bananas remaining in pile 0: -1
# 		incrementing current pile to: 1
# 	current pile: 1
# 		bananas remaining in pile 1: 2
# 		bananas remaining in pile 1: -2
# 		incrementing current pile to: 2
# 	current pile: 2
# 		bananas remaining in pile 2: 3
# 		bananas remaining in pile 2: -1
# 		incrementing current pile to: 3
# 	current pile: 3
# 		bananas remaining in pile 3: 7
# 		bananas remaining in pile 3: 3
# 		bananas remaining in pile 3: -1
# 		incrementing current pile to: 4
# 	checking success of rate 4 resulting in 27 eaten: True
# Result: 4
# Answer is correct: True
#
#
# *** Case 2 ***
# piles: [30, 11, 23, 4, 20]	h: 5	Output: 30
# piles: [4, 11, 20, 23, 30]
# 	total bananas: 88	Min speed: 17.6	average bananas per pile: 17.6	piles/hour: 1.0
# 	current pile: 0
# 		bananas remaining in pile 0: -26
# ...

# %% [markdown]
# ### 1.2

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def minEatingSpeed(self, piles, h):
        """
        :type piles: List[int]
        :type h: int
        :rtype: int
        """
        self.piles = sorted(piles)
        self.h = h
        self.total_n = sum(piles)
        piles_per_hour = len(piles) / h
        average_n_per_pile = self.total_n/len(piles)
        min_eating_speed = self.total_n / h
        print(f"piles: {self.piles}")
        print(f"\ttotal bananas: {self.total_n}\tMin speed: {min_eating_speed}\taverage bananas per pile: {average_n_per_pile}\tpiles/hour: {piles_per_hour}")
        if piles_per_hour >= 1:
            result = self.piles[-1]
        elif piles_per_hour > 0.5:
            result_index = 1
            while self.checkSuccess(self.piles[result_index]) == False:
                result_index += 1
            result = self.piles[result_index]
        else:
            result = round((self.total_n + 1) / h)
            while self.checkSuccess(result) == False:
                result += 1
        return result
        
    def checkSuccess(self, eating_speed):
        eaten = 0
        current_pile = 0
        hour = 1

        # for hour in range(self.h):
        while hour <= self.h and current_pile < len(self.piles):
            print(f"\tcurrent pile: {current_pile}")
            bananas_in_current_pile = self.piles[current_pile]
            while bananas_in_current_pile > 0:
                eaten += min(bananas_in_current_pile, eating_speed)
                bananas_in_current_pile -= eating_speed
                print(f"\t\tbananas remaining in pile {current_pile}: {bananas_in_current_pile}")
                hour += 1
            current_pile += 1
            print(f"\t\tincrementing current pile to: {current_pile}")
        isSuccess = eaten >= self.total_n
        print(f"\tchecking success of rate {eating_speed} resulting in {eaten} eaten: {isSuccess}")
        return isSuccess

cases = {
    # 1: {
    #     "piles": [3,6,7,11], 
    #     "h": 8,
    #     "Output": 4
    # },
    # 2: {
    #     "piles": [30,11,23,4,20], 
    #     "h": 5,
    #     "Output": 30
    # },
    # 3: {
    #     "piles": [30,11,23,4,20], 
    #     "h": 6,
    #     "Output": 23
    # },
    4: {
        "piles": [30,11,23,4,20], 
        "h": 7,
        "Output": 20
    },
    # 5: {
    #     "piles": [3,6,7,14], 
    #     "h": 8,
    #     "Output": 5
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    piles = case["piles"]
    h = case["h"]
    Output = case["Output"]

    result = solution.minEatingSpeed(piles, h)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 4 ***
# piles: [30, 11, 23, 4, 20]	h: 7	Output: 20
# piles: [4, 11, 20, 23, 30]
# 	total bananas: 88	Min speed: 12.571428571428571	average bananas per pile: 17.6	piles/hour: 0.7142857142857143
# 	current pile: 0
# 		bananas remaining in pile 0: -7
# 		incrementing current pile to: 1
# 	current pile: 1
# 		bananas remaining in pile 1: 0
# 		incrementing current pile to: 2
# 	current pile: 2
# 		bananas remaining in pile 2: 9
# 		bananas remaining in pile 2: -2
# 		incrementing current pile to: 3
# 	current pile: 3
# 		bananas remaining in pile 3: 12
# 		bananas remaining in pile 3: 1
# 		bananas remaining in pile 3: -10
# 		incrementing current pile to: 4
# 	checking success of rate 11 resulting in 58 eaten: False
# 	current pile: 0
# 		bananas remaining in pile 0: -16
# 		incrementing current pile to: 1
# 	current pile: 1
# 		bananas remaining in pile 1: -9
# 		incrementing current pile to: 2
# 	current pile: 2
# 		bananas remaining in pile 2: 0
# ...

# %% [markdown]
# ### 1.3

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def minEatingSpeed(self, piles, h):
        """
        :type piles: List[int]
        :type h: int
        :rtype: int
        """
        self.piles = sorted(piles)
        self.h = h
        self.total_n = sum(piles)
        piles_per_hour = len(piles) / h
        average_n_per_pile = self.total_n/len(piles)
        min_eating_speed = self.total_n / h
        # print(f"piles: {self.piles}")
        # print(f"\ttotal bananas: {self.total_n}\tMin speed: {min_eating_speed}\taverage bananas per pile: {average_n_per_pile}\tpiles/hour: {piles_per_hour}")
        if piles_per_hour >= 1:
            result = self.piles[-1]
        elif piles_per_hour > 0.5:
            result_index = 1
            while self.checkSuccess(self.piles[result_index]) == False:
                result_index += 1
            result = self.piles[result_index]
        else:
            result = round((self.total_n + 1) / h)
            while self.checkSuccess(result) == False:
                result += 1
        return result
        
    def checkSuccess(self, eating_speed):
        eaten = 0
        current_pile = 0
        hour = 0
        while hour < self.h and current_pile < len(self.piles):
            # print(f"\tcurrent pile: {current_pile}")
            bananas_in_current_pile = self.piles[current_pile]
            while bananas_in_current_pile > 0 and hour < self.h:
                eaten += min(bananas_in_current_pile, eating_speed)
                bananas_in_current_pile -= eating_speed
                hour += 1
                # print(f"\t\tbananas eaten: {eaten}\tbananas remaining in pile {current_pile}: {bananas_in_current_pile}\tNext hour: {hour}")
            current_pile += 1
            # print(f"\t\tincrementing current pile to: {current_pile}")
        isSuccess = eaten >= self.total_n
        # print(f"\tchecking success of rate {eating_speed} resulting in {eaten} eaten: {isSuccess}")
        return isSuccess

cases = {
    1: {
        "piles": [3,6,7,11], 
        "h": 8,
        "Output": 4
    },
    2: {
        "piles": [30,11,23,4,20], 
        "h": 5,
        "Output": 30
    },
    3: {
        "piles": [30,11,23,4,20], 
        "h": 6,
        "Output": 23
    },
    4: {
        "piles": [30,11,23,4,20], 
        "h": 7,
        "Output": 20
    },
    5: {
        "piles": [3,6,7,14], 
        "h": 8,
        "Output": 5
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    piles = case["piles"]
    h = case["h"]
    Output = case["Output"]

    result = solution.minEatingSpeed(piles, h)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# piles: [3, 6, 7, 11]	h: 8	Output: 4
# Result: 4
# Answer is correct: True
#
#
# *** Case 2 ***
# piles: [30, 11, 23, 4, 20]	h: 5	Output: 30
# Result: 30
# Answer is correct: True
#
#
# *** Case 3 ***
# piles: [30, 11, 23, 4, 20]	h: 6	Output: 23
# Result: 23
# Answer is correct: True
#
#
# *** Case 4 ***
# piles: [30, 11, 23, 4, 20]	h: 7	Output: 20
# Result: 20
# Answer is correct: True
#
#
# *** Case 5 ***
# piles: [3, 6, 7, 14]	h: 8	Output: 5
# Result: 5
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# # *End of Page*
