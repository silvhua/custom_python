# %% [markdown]
# # Network Delay Time
# * [LeetCode link]()
# * [NeetCode link](https://neetcode.io/problems/network-delay-time/question?list=neetcode150)
#
# You are given a network of `n` directed nodes, labeled from `1` to `n`. You are also given `times`, a list of directed edges where `times[i] = (ui, vi, ti)`.
#
# * `ui` is the source node (an integer from `1` to `n`)
# * `vi` is the target node (an integer from `1` to `n`)
# * `ti` is the time it takes for a signal to travel from the source to the target node (an integer greater than or equal to 0).
# You are also given an integer `k`, representing the node that we will send a signal from.
#
# Return the minimum time it takes for all of the `n` nodes to receive the signal. If it is impossible for all the nodes to receive the signal, return `-1` instead.
#
# Example 1:
# ```
# Input: times = [[1,2,1],[2,3,1],[1,4,4],[3,4,1]], n = 4, k = 1
#
# Output: 3
# ```
# Example 2:
# ```
# Input: times = [[1,2,1],[2,3,1]], n = 3, k = 2
#
# Output: -1
# ```
# Constraints:
#
# * `1 <= k <= n <= 100`
# * `1 <= times.length <= 1000`
#
# ## Skeleton code
# ```python
# class Solution:
#     def networkDelayTime(self, times: List[List[int]], n: int, k: int) -> int:
# ```

# %% [markdown]
# ## Iteration 1
# * Time: $ O() $
# * Space: $ O() $

# %%
import sys
sys.path.append(r"/Users/silvh/Library/CloudStorage/OneDrive-Personal/lighthouse/custom_python")
from Custom_Logger import create_function_logger

# %%
from typing import List
import sys
sys.path.append(r"/Users/silvh/Library/CloudStorage/OneDrive-Personal/lighthouse/custom_python")
from Custom_Logger import create_function_logger
import heapq

class Solution:
    def networkDelayTime(self, times: List[List[int]], n: int, k: int) -> int:
        self.logger = create_function_logger(__name__, None)
        self.log_messages = []
        self.edges = times
        self.createGraph(n)
        self.times = {}
        heap = [(k, 0)]
        while heap:
            current, distance = heapq.heappop(heap)
            self.log_messages.append(f"Popped from heap: {current}\tDistance: {distance}")
            if current not in self.times:
                self.times[current] = distance
            neighbors = self.paths[current]
            for neighbor, distance in neighbors:
                heapq.heappush(heap, (neighbor, distance))

        if len(self.times) == n:
            result = sum([time for time in self.times.values()])
        else:
            self.log_messages.append(f"Not all nodes can be reached")
            result = -1
        self.logger.info("\t" + "\n\t".join(self.log_messages))
        return result
        
    def createGraph(self, n_nodes):
        self.paths = {}
        for i in range(1, n_nodes + 1):
            self.paths[i] = []
        for source, target, time in self.edges:
            self.paths[source].append((target, time))
        self.log_messages.append("Paths:")
        for key, value in self.paths.items():
            self.log_messages.append(f"\tnode: {key}\t(neighbor, distance): {value}")

        return self.paths
    
cases = {
    1: {
        "times": [[1,2,1],[2,3,1],[1,4,4],[3,4,1]], 
        "n": 4, 
        "k": 1,
        "Output": 3 
    },
    2: {
        "times": [[1,2,1],[2,3,1]], 
        "n": 3, 
        "k": 2,
        "Output": -1
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    times = case["times"]
    n = case["n"]
    k = case["k"]
    Output = case["Output"]
    result = solution.networkDelayTime(times, n, k)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# 2026-07-26 20:41:37,661 - __main__ - INFO:
# 	Paths:
# 		node: 1	(neighbor, distance): [(2, 1), (4, 4)]
# 		node: 2	(neighbor, distance): [(3, 1)]
# 		node: 3	(neighbor, distance): [(4, 1)]
# 		node: 4	(neighbor, distance): []
# 	Popped from heap: 1	Distance: 0
# 	Popped from heap: 2	Distance: 1
# 	Popped from heap: 3	Distance: 1
# 	Popped from heap: 4	Distance: 1
# 	Popped from heap: 4	Distance: 4
#
# 2026-07-26 20:41:37,662 - __main__ - INFO:
# 	Paths:
# 		node: 1	(neighbor, distance): [(2, 1)]
# 		node: 2	(neighbor, distance): [(3, 1)]
# 		node: 3	(neighbor, distance): []
# 	Popped from heap: 2	Distance: 0
# 	Popped from heap: 3	Distance: 1
# 	Not all nodes can be reached
# *** Case 1 ***
# times: [[1, 2, 1], [2, 3, 1], [1, 4, 4], [3, 4, 1]]	n: 4	k: 1	Output: 3
# Result: 3
# Answer is correct: True
#
#
# *** Case 2 ***
# times: [[1, 2, 1], [2, 3, 1]]	n: 3	k: 2	Output: -1
# Result: -1
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ## 1.1 clean up for submission
# * Time: $ O(n log m) $ where m is `len(times)`
# * Space: $ O(n + m) $

# %%
from typing import List
import sys
sys.path.append(r"/Users/silvh/Library/CloudStorage/OneDrive-Personal/lighthouse/custom_python")
from Custom_Logger import create_function_logger
import heapq

class Solution:
    def networkDelayTime(self, times: List[List[int]], n: int, k: int) -> int:
        # self.logger = create_function_logger(__name__, None)
        self.log_messages = []
        self.edges = times
        self.createGraph(n)
        self.times = {}
        heap = [(k, 0)]
        while heap:
            current, distance = heapq.heappop(heap)
            self.log_messages.append(f"Popped from heap: {current}\tDistance: {distance}")
            if current not in self.times:
                self.times[current] = distance
            neighbors = self.paths[current]
            for neighbor, distance in neighbors:
                heapq.heappush(heap, (neighbor, distance))

        if len(self.times) == n:
            result = sum([time for time in self.times.values()])
        else:
            self.log_messages.append(f"Not all nodes can be reached")
            result = -1
        print("\t" + "\n\t".join(self.log_messages))
        return result
        
    def createGraph(self, n_nodes):
        self.paths = {}
        for i in range(1, n_nodes + 1):
            self.paths[i] = []
        for source, target, time in self.edges:
            self.paths[source].append((target, time))
        self.log_messages.append("Paths:")
        for key, value in self.paths.items():
            self.log_messages.append(f"\tnode: {key}\t(neighbor, distance): {value}")

        return self.paths
    
cases = {
    # 1: {
    #     "times": [[1,2,1],[2,3,1],[1,4,4],[3,4,1]], 
    #     "n": 4, 
    #     "k": 1,
    #     "Output": 3 
    # },
    # 2: {
    #     "times": [[1,2,1],[2,3,1]], 
    #     "n": 3, 
    #     "k": 2,
    #     "Output": -1
    # },
    3: {
        "times": [[2,1,1],[2,3,1],[3,4,1]], 
        "n": 4, 
        "k": 2,
        "Output": 2
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    times = case["times"]
    n = case["n"]
    k = case["k"]
    Output = case["Output"]
    result = solution.networkDelayTime(times, n, k)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 3 ***
# times: [[2, 1, 1], [2, 3, 1], [3, 4, 1]]	n: 4	k: 2	Output: 2
# 	Paths:
# 		node: 1	(neighbor, distance): []
# 		node: 2	(neighbor, distance): [(1, 1), (3, 1)]
# 		node: 3	(neighbor, distance): [(4, 1)]
# 		node: 4	(neighbor, distance): []
# 	Popped from heap: 2	Distance: 0
# 	Popped from heap: 1	Distance: 1
# 	Popped from heap: 3	Distance: 1
# 	Popped from heap: 4	Distance: 1
# Result: 3
# Answer is correct: False
#
#
#
# ***** All cases correct: False *****

# %% [markdown]
# # iteration 2

# %%
from typing import List
import sys
sys.path.append(r"/Users/silvh/Library/CloudStorage/OneDrive-Personal/lighthouse/custom_python")
from Custom_Logger import create_function_logger
import heapq

class Solution:
    def networkDelayTime(self, times: List[List[int]], n: int, k: int) -> int:
        # self.logger = create_function_logger(__name__, None)
        self.log_messages = []
        self.edges = times
        self.createGraph(n)
        self.times = {}
        heap = [(k, 0)]
        while heap:
            current, distance1 = heapq.heappop(heap)
            self.log_messages.append(f"Popped from heap: {current}\tDistance: {distance1}")
            if current not in self.times:
                self.times[current] = distance1
            neighbors = self.paths[current]
            if len(neighbors) > 0:
                # Account for when the source node is directed at more than one neighbor
                furthest_distance, furthest_neighbor = sorted(neighbors, key = lambda x: x[1])[0]
                for neighbor, distance2 in neighbors:
                    distance = furthest_distance if neighbor == furthest_neighbor else 0
                    heapq.heappush(heap, (neighbor, distance))

        if len(self.times) == n:
            result = sum([time for time in self.times.values()])

        else:
            self.log_messages.append(f"Not all nodes can be reached")
            result = -1
        print("\t" + "\n\t".join(self.log_messages))
        return result
        
    def createGraph(self, n_nodes):
        self.paths = {}
        for i in range(1, n_nodes + 1):
            self.paths[i] = []
        for source, target, time in self.edges:
            self.paths[source].append((target, time))
        self.log_messages.append("Paths:")
        for key, value in self.paths.items():
            self.log_messages.append(f"\tnode: {key}\t(neighbor, distance): {value}")

        return self.paths
    
cases = {
    # 1: {
    #     "times": [[1,2,1],[2,3,1],[1,4,4],[3,4,1]], 
    #     "n": 4, 
    #     "k": 1,
    #     "Output": 3 
    # },
    # 2: {
    #     "times": [[1,2,1],[2,3,1]], 
    #     "n": 3, 
    #     "k": 2,
    #     "Output": -1
    # },
    3: {
        "times": [[2,1,1],[2,3,1],[3,4,1]], 
        "n": 4, 
        "k": 2,
        "Output": 2
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    times = case["times"]
    n = case["n"]
    k = case["k"]
    Output = case["Output"]
    result = solution.networkDelayTime(times, n, k)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 3 ***
# times: [[2, 1, 1], [2, 3, 1], [3, 4, 1]]	n: 4	k: 2	Output: 2
# 	Paths:
# 		node: 1	(neighbor, distance): []
# 		node: 2	(neighbor, distance): [(1, 1), (3, 1)]
# 		node: 3	(neighbor, distance): [(4, 1)]
# 		node: 4	(neighbor, distance): []
# 	Popped from heap: 2	Distance: 0
# 	Popped from heap: 1	Distance: 1
# 	Popped from heap: 3	Distance: 0
# 	Popped from heap: 4	Distance: 0
# Result: 1
# Answer is correct: False
#
#
#
# ***** All cases correct: False *****

# %%
list = [("a", 4), ("b", 1), ("c", 2)]
sorted(list, key = lambda item: item[1])
# Out:
# [('b', 1), ('c', 2), ('a', 4)]

# %% [markdown]
# ## 2.1

# %%
from typing import List
import sys
sys.path.append(r"/Users/silvh/Library/CloudStorage/OneDrive-Personal/lighthouse/custom_python")
from Custom_Logger import create_function_logger
import heapq

class Solution:
    def networkDelayTime(self, times: List[List[int]], n: int, k: int) -> int:
        # self.logger = create_function_logger(__name__, None)
        self.log_messages = []
        self.edges = times
        self.createGraph(n)
        self.times = {}
        heap = [(k, 0)]
        while heap:
            current, distance1 = heapq.heappop(heap)
            self.log_messages.append(f"Popped from heap: {current}\tDistance: {distance1}")
            if current not in self.times:
                self.times[current] = distance1
            neighbors = self.paths[current]
            if len(neighbors) > 1:
                # Account for when the source node is directed at more than one neighbor
                furthest_distance, furthest_neighbor = sorted(neighbors, key = lambda x: x[1])[0]
                for neighbor, distance2 in neighbors:
                    distance = furthest_distance if neighbor == furthest_neighbor else 0
                    heapq.heappush(heap, (neighbor, distance1 + distance))
            else:
                for neighbor, distance2 in neighbors:
                    heapq.heappush(heap, (neighbor, distance2))


        if len(self.times) == n:
            result = sum([time for time in self.times.values()])

        else:
            self.log_messages.append(f"Not all nodes can be reached")
            result = -1
        for key, value in self.times.items():
            self.log_messages.append(f"\tnode: {key}\ttime: {value}")
        print("\t" + "\n\t".join(self.log_messages))
        return result
        
    def createGraph(self, n_nodes):
        self.paths = {}
        for i in range(1, n_nodes + 1):
            self.paths[i] = []
        for source, target, time in self.edges:
            self.paths[source].append((target, time))
        self.log_messages.append("Paths:")
        for key, value in self.paths.items():
            self.log_messages.append(f"\tnode: {key}\t(neighbor, distance): {value}")

        return self.paths
    
cases = {
    1: {
        "times": [[1,2,1],[2,3,1],[1,4,4],[3,4,1]], 
        "n": 4, 
        "k": 1,
        "Output": 3 
    },
    2: {
        "times": [[1,2,1],[2,3,1]], 
        "n": 3, 
        "k": 2,
        "Output": -1
    },
    3: {
        "times": [[2,1,1],[2,3,1],[3,4,1]], 
        "n": 4, 
        "k": 2,
        "Output": 2
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    times = case["times"]
    n = case["n"]
    k = case["k"]
    Output = case["Output"]
    result = solution.networkDelayTime(times, n, k)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# times: [[1, 2, 1], [2, 3, 1], [1, 4, 4], [3, 4, 1]]	n: 4	k: 1	Output: 3
# 	Paths:
# 		node: 1	(neighbor, distance): [(2, 1), (4, 4)]
# 		node: 2	(neighbor, distance): [(3, 1)]
# 		node: 3	(neighbor, distance): [(4, 1)]
# 		node: 4	(neighbor, distance): []
# 	Popped from heap: 1	Distance: 0
# 	Popped from heap: 2	Distance: 0
# 	Popped from heap: 3	Distance: 1
# 	Popped from heap: 4	Distance: 0
# 	Popped from heap: 4	Distance: 1
# 		node: 1	time: 0
# 		node: 2	time: 0
# 		node: 3	time: 1
# 		node: 4	time: 0
# Result: 1
# Answer is correct: False
#
#
# *** Case 2 ***
# times: [[1, 2, 1], [2, 3, 1]]	n: 3	k: 2	Output: -1
# 	Paths:
# 		node: 1	(neighbor, distance): [(2, 1)]
# 		node: 2	(neighbor, distance): [(3, 1)]
# 		node: 3	(neighbor, distance): []
# 	Popped from heap: 2	Distance: 0
# 	Popped from heap: 3	Distance: 1
# 	Not all nodes can be reached
# 		node: 2	time: 0
# 		node: 3	time: 1
# Result: -1
# Answer is correct: True
#
#
# *** Case 3 ***
# ...

# %% [markdown]
# ## 2.2

# %%
from typing import List
import sys
sys.path.append(r"/Users/silvh/Library/CloudStorage/OneDrive-Personal/lighthouse/custom_python")
from Custom_Logger import create_function_logger
import heapq

class Solution:
    def networkDelayTime(self, times: List[List[int]], n: int, k: int) -> int:
        # self.logger = create_function_logger(__name__, None)
        self.log_messages = []
        self.edges = times
        self.createGraph(n)
        self.times = {}
        heap = [(k, 0)]
        while heap:
            current, distance1 = heapq.heappop(heap)
            self.log_messages.append(f"Popped from heap: {current}\tDistance: {distance1}")
            if current not in self.times:
                self.times[current] = distance1
            neighbors = self.paths[current]
            if len(neighbors) > 1:
                # Account for when the source node is directed at more than one neighbor
                furthest_distance, furthest_neighbor = sorted(neighbors, key = lambda x: x[1])[0]
                for neighbor, distance2 in neighbors:
                    distance = furthest_distance if neighbor == furthest_neighbor else 0
                    heapq.heappush(heap, (neighbor, distance1 + distance))
            else:
                for neighbor, distance2 in neighbors:
                    heapq.heappush(heap, (neighbor, distance2))


        if len(self.times) == n:
            result = sum([time for time in self.times.values()])

        else:
            self.log_messages.append(f"Not all nodes can be reached")
            result = -1
        for key, value in self.times.items():
            self.log_messages.append(f"\tnode: {key}\ttime: {value}")
        print("\t" + "\n\t".join(self.log_messages))
        return result
        
    def createGraph(self, n_nodes):
        self.paths = {}
        for i in range(1, n_nodes + 1):
            self.paths[i] = []
        for source, target, time in self.edges:
            self.paths[source].append((target, time))
        self.log_messages.append("Paths:")
        for key, value in self.paths.items():
            self.log_messages.append(f"\tnode: {key}\t(neighbor, distance): {value}")

        return self.paths
    
cases = {
    1: {
        "times": [[1,2,1],[2,3,1],[1,4,4],[3,4,1]], 
        "n": 4, 
        "k": 1,
        "Output": 3 
    },
    # 2: {
    #     "times": [[1,2,1],[2,3,1]], 
    #     "n": 3, 
    #     "k": 2,
    #     "Output": -1
    # },
    # 3: {
    #     "times": [[2,1,1],[2,3,1],[3,4,1]], 
    #     "n": 4, 
    #     "k": 2,
    #     "Output": 2
    # }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    times = case["times"]
    n = case["n"]
    k = case["k"]
    Output = case["Output"]
    result = solution.networkDelayTime(times, n, k)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# times: [[1, 2, 1], [2, 3, 1], [1, 4, 4], [3, 4, 1]]	n: 4	k: 1	Output: 3
# 	Paths:
# 		node: 1	(neighbor, distance): [(2, 1), (4, 4)]
# 		node: 2	(neighbor, distance): [(3, 1)]
# 		node: 3	(neighbor, distance): [(4, 1)]
# 		node: 4	(neighbor, distance): []
# 	Popped from heap: 1	Distance: 0
# 	Popped from heap: 2	Distance: 0
# 	Popped from heap: 3	Distance: 1
# 	Popped from heap: 4	Distance: 0
# 	Popped from heap: 4	Distance: 1
# 		node: 1	time: 0
# 		node: 2	time: 0
# 		node: 3	time: 1
# 		node: 4	time: 0
# Result: 1
# Answer is correct: False
#
#
#
# ***** All cases correct: False *****

# %% [markdown]
# # *End of Page*
