# %% [markdown]
# # Search in a Binary Search Tree
# * [LeetCode link](https://leetcode.com/problems/search-in-a-binary-search-tree/)
#
# You are given the `root` of a binary search tree (BST) and an integer `val`.
#
# Find the node in the BST that the node's value equals `val` and return the subtree rooted with that node. If such a node does not exist, return `null`.
#
# Example 1:
#
# ```
# Input: root = [4,2,7,1,3], val = 2
# Output: [2,1,3]
# ```
# Example 2:
#
# ```
# Input: root = [4,2,7,1,3], val = 5
# Output: []
# ```
#
# Constraints:
#
# * The number of nodes in the tree is in the range [1, 5000].
# * 1 <= Node.val <= $ 10^7 $
# * `root` is a binary search tree.
# * 1 <= val <= $ 10^7 $
# ## Skeleton code
# ```python
# # Definition for a binary tree node.
# # class TreeNode(object):
# #     def __init__(self, val=0, left=None, right=None):
# #         self.val = val
# #         self.left = left
# #         self.right = right
# class Solution(object):
#     def searchBST(self, root, val):
#         """
#         :type root: Optional[TreeNode]
#         :type val: int
#         :rtype: Optional[TreeNode]
#         """
# ```

# %% [markdown]
# ## Build the tree

# %%
from typing import Deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    # def searchBST(self, root, val):
    

    def bfs(self, root):
        queue = Deque()
        self.level_sums = {}

        queue.append(root)
        self.level_sums[1] = root.val
    
        level = 1
        while len(queue) > 0:
            level_sum = 0
            for i in range(len(queue)):
                curr = queue.popleft()
                if (curr.val):
                    level_sum += curr.val
                if curr.left:
                    queue.append(curr.left)
                if curr.right:
                    queue.append(curr.right)
                self.level_sums[level] = level_sum
            level += 1

    def printLevelSums(self):
        print(f"\tlevel sums:")
        for key, value in self.level_sums.items():
            print(f'\t\t{key}: {value}')

    def buildTree(self, nodes):
        # Treat the tree as a heap
        nodes = [None] + nodes
        self.tree = self.createNode(1, nodes)
        return self.tree

    def createNode(self, index, nodes):
        if index >= len(nodes):
            # print(f"\tindex exceeded\n\t\tindex: {index}\t# of nodes: {len(nodes)}")
            return None
        left_child_index = index * 2
        
        ## handle case if the node is the right child and its older sibling is None
        if index % 2 == 1 and nodes[index - 1] == None and index > 1:
            print(f"\t** adjusting children indices and nodes list")
            nodes = nodes[index - 1:]
            index = 1
            left_child_index = 2
        right_child_index = left_child_index + 1
        val = nodes[index]
        # print(f"\tcreateNode index: {index}\tvalue: {val}")
        # print(f"\t\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        if val:
            node = TreeNode(
                val,
                self.createNode(left_child_index, nodes),
                self.createNode(right_child_index, nodes)
                )
        else:
            node = TreeNode(val, None, None)
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            nodes_list.append(None)
            return
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")
        return nodes_list

    def addToNodesList(self, node, nodes_list, index=1):
        if not node:

            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)

        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)


cases = {
    1: {
        "root": [4,2,7,1,3], 
        "val": 2,
        "Output": [2,1,3]
    },
    2: {
        
        "root": [4,2,7,1,3], 
        "val": 5,
        "Output": []
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    root = case["root"]
    Output = case["Output"]

    tree = solution.buildTree(root)
    tree_nodes = solution.printNodes(tree, [])
    print(f"** Tree nodes match input: {tree_nodes == root}")

    # result = solution.
    # correct_for_case = result == Output
    # print(f"Result: {result}")
    # correct.append(correct_for_case)
    # print(f"Answer is correct: {correct_for_case}\n\n")
# print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# root: [4, 2, 7, 1, 3]	val: 2	Output: [2, 1, 3]
# Tree nodes: [4, 2, 7, 1, 3]
# ** Tree nodes match input: True
# *** Case 2 ***
# root: [4, 2, 7, 1, 3]	val: 5	Output: []
# Tree nodes: [4, 2, 7, 1, 3]
# ** Tree nodes match input: True

# %% [markdown]
# ## Iteration 1
# * Time: $ O(N) $
# * Space: $ O(N) $

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def searchBST(self, root, val):
        queue = deque()
        if not root:
            return []
        if root.val == val:
            return self.printNodes(root, [])

        queue.append(root)
    
        while len(queue) > 0:
            for i in range(len(queue)):
                curr = queue.popleft()
                if curr.val:
                    if curr.val == val:
                        return self.printNodes(curr, [])
                    if curr.left:
                        queue.append(curr.left)
                    if curr.right:
                        queue.append(curr.right)
        return []

    def bfs_level_sum(self, root):
        queue = Deque()
        self.level_sums = {}

        queue.append(root)
        self.level_sums[1] = root.val
    
        level = 1
        while len(queue) > 0:
            level_sum = 0
            for i in range(len(queue)):
                curr = queue.popleft()
                if (curr.val):
                    level_sum += curr.val
                if curr.left:
                    queue.append(curr.left)
                if curr.right:
                    queue.append(curr.right)
                self.level_sums[level] = level_sum
            level += 1

    def printLevelSums(self):
        print(f"\tlevel sums:")
        for key, value in self.level_sums.items():
            print(f'\t\t{key}: {value}')

    def buildTree(self, nodes):
        # Treat the tree as a heap
        nodes = [None] + nodes
        self.tree = self.createNode(1, nodes)
        return self.tree

    def createNode(self, index, nodes):
        if index >= len(nodes):
            # print(f"\tindex exceeded\n\t\tindex: {index}\t# of nodes: {len(nodes)}")
            return None
        left_child_index = index * 2
        
        ## handle case if the node is the right child and its older sibling is None
        if index % 2 == 1 and nodes[index - 1] == None and index > 1:
            print(f"\t** adjusting children indices and nodes list")
            nodes = nodes[index - 1:]
            index = 1
            left_child_index = 2
        right_child_index = left_child_index + 1
        val = nodes[index]
        # print(f"\tcreateNode index: {index}\tvalue: {val}")
        # print(f"\t\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        if val:
            node = TreeNode(
                val,
                self.createNode(left_child_index, nodes),
                self.createNode(right_child_index, nodes)
                )
        else:
            node = TreeNode(val, None, None)
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            nodes_list.append(None)
            return
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")
        return nodes_list

    def addToNodesList(self, node, nodes_list, index=1):
        if not node:

            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)

        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)


cases = {
    1: {
        "root": [4,2,7,1,3], 
        "val": 2,
        "Output": [2,1,3]
    },
    2: {
        
        "root": [4,2,7,1,3], 
        "val": 5,
        "Output": []
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    root = case["root"]
    val = case["val"]
    Output = case["Output"]

    tree = solution.buildTree(root)
    tree_nodes = solution.printNodes(tree, [])
    print(f"** Tree nodes match input: {tree_nodes == root}")

    result = solution.searchBST(tree, val)
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# root: [4, 2, 7, 1, 3]	val: 2	Output: [2, 1, 3]
# Tree nodes: [4, 2, 7, 1, 3]
# ** Tree nodes match input: True
# Tree nodes: [2, 1, 3]
# Result: [2, 1, 3]
# Answer is correct: True
#
#
# *** Case 2 ***
# root: [4, 2, 7, 1, 3]	val: 5	Output: []
# Tree nodes: [4, 2, 7, 1, 3]
# ** Tree nodes match input: True
# Result: []
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# ### 1.1 Accepted
# * Runtime 16 ms Beats 5.05%
# * Memory 16.61 MB Beats 3.79%

# %%
from collections import deque

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def searchBST(self, root, val):
        queue = deque()
        if not root:
            return None
        if root.val == val:
            return root

        queue.append(root)
    
        while len(queue) > 0:
            for i in range(len(queue)):
                curr = queue.popleft()
                if curr.val:
                    if curr.val == val:
                        return curr
                    if curr.left:
                        queue.append(curr.left)
                    if curr.right:
                        queue.append(curr.right)
        return None

    def bfs_level_sum(self, root):
        queue = Deque()
        self.level_sums = {}

        queue.append(root)
        self.level_sums[1] = root.val
    
        level = 1
        while len(queue) > 0:
            level_sum = 0
            for i in range(len(queue)):
                curr = queue.popleft()
                if (curr.val):
                    level_sum += curr.val
                if curr.left:
                    queue.append(curr.left)
                if curr.right:
                    queue.append(curr.right)
                self.level_sums[level] = level_sum
            level += 1

    def printLevelSums(self):
        print(f"\tlevel sums:")
        for key, value in self.level_sums.items():
            print(f'\t\t{key}: {value}')

    def buildTree(self, nodes):
        # Treat the tree as a heap
        nodes = [None] + nodes
        self.tree = self.createNode(1, nodes)
        return self.tree

    def createNode(self, index, nodes):
        if index >= len(nodes):
            # print(f"\tindex exceeded\n\t\tindex: {index}\t# of nodes: {len(nodes)}")
            return None
        left_child_index = index * 2
        
        ## handle case if the node is the right child and its older sibling is None
        if index % 2 == 1 and nodes[index - 1] == None and index > 1:
            print(f"\t** adjusting children indices and nodes list")
            nodes = nodes[index - 1:]
            index = 1
            left_child_index = 2
        right_child_index = left_child_index + 1
        val = nodes[index]
        # print(f"\tcreateNode index: {index}\tvalue: {val}")
        # print(f"\t\tleft child index: {left_child_index}\tright child index: {right_child_index}")
        if val:
            node = TreeNode(
                val,
                self.createNode(left_child_index, nodes),
                self.createNode(right_child_index, nodes)
                )
        else:
            node = TreeNode(val, None, None)
        return node
    
    def printNodes(self, root, nodes_list = []):
        if not root:
            return nodes_list
        nodes_list.append(root.val)
        self.addToNodesList(root, nodes_list)
        print(f"Tree nodes: {[val for val in nodes_list]}")
        return nodes_list

    def addToNodesList(self, node, nodes_list, index=1):
        if not node:

            return
        if node.left:
            nodes_list.append(node.left.val)
        if node.right:
            nodes_list.append(node.right.val)

        self.addToNodesList(node.left, nodes_list)
        self.addToNodesList(node.right, nodes_list)


cases = {
    1: {
        "root": [4,2,7,1,3], 
        "val": 2,
        "Output": [2,1,3]
    },
    2: {
        
        "root": [4,2,7,1,3], 
        "val": 5,
        "Output": []
    }
}

correct = []
solution = Solution()

for case_number in cases:
    case = cases[case_number]
    print(f"*** Case {case_number} ***")
    for key in case.keys():
        print(f"{key}: {case[key]}", end="\t")
    print("")
    
    root = case["root"]
    val = case["val"]
    Output = case["Output"]

    tree = solution.buildTree(root)
    tree_nodes = solution.printNodes(tree, [])
    print(f"** Tree nodes match input: {tree_nodes == root}")

    subtree = solution.searchBST(tree, val)
    result = solution.printNodes(subtree, [])
    correct_for_case = result == Output
    print(f"Result: {result}")
    correct.append(correct_for_case)
    print(f"Answer is correct: {correct_for_case}\n\n")
print(f"\n***** All cases correct: {sum(correct) == len(correct)} *****")
# Out:
# *** Case 1 ***
# root: [4, 2, 7, 1, 3]	val: 2	Output: [2, 1, 3]
# Tree nodes: [4, 2, 7, 1, 3]
# ** Tree nodes match input: True
# Tree nodes: [2, 1, 3]
# Result: [2, 1, 3]
# Answer is correct: True
#
#
# *** Case 2 ***
# root: [4, 2, 7, 1, 3]	val: 5	Output: []
# Tree nodes: [4, 2, 7, 1, 3]
# ** Tree nodes match input: True
# Result: []
# Answer is correct: True
#
#
#
# ***** All cases correct: True *****

# %% [markdown]
# # *End of Page*
