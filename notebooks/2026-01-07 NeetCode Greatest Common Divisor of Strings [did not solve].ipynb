# %% [markdown]
# # Greatest Common Divisor of Strings [did not solve]
# * [NeetCode link](https://neetcode.io/problems/greatest-common-divisor-of-strings/question?list=allNC)
# * [LeetCode link](https://leetcode.com/problems/greatest-common-divisor-of-strings/description/)
#
# For two strings `s` and `t`, we say "`t` divides `s`" if and only if `s = t + t + t + ... + t + t` (i.e., `t` is concatenated with itself one or more times).
#
# You are given two strings `str1` and `str2`, return the largest string `x` such that `x` divides both `str1` and `str2`. If there is no such string, return `""`.
#
# Example 1:
# ```
# Input: str1 = "ABAB", str2 = "AB"
#
# Output: "AB"
# ```
# Example 2:
# ```
# Input: str1 = "NANANA", str2 = "NANA"
#
# Output: "NA"
# ```
# Constraints:
#
# * `1 <= str1.length, str2.length <= 1000`
# * `str1 and str2 consist of English uppercase letters.`
#
# ## Skeleton code
# ```python
# class Solution:
#     def gcdOfStrings(self, str1: str, str2: str) -> str:
# ```

# %% [markdown]
# ## Iteration 1
# * Time: O()
# * Space: O()

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        divisor = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                divisor += str1[i]
            else:
                print(f"Characters no longer match")
                break
        divisor = ""
        
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

str1 = "NANANA"
str2 = "NANA"

Output = "NA"
solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: NANANA; String 2: NANA
# 	Index: 0	N	N
# 	Index: 1	A	A
# 	Index: 2	N	N
# 	Index: 3	A	A
# divisor:  (length: 0)
# Answer is correct: False

# %% [markdown]
# ### 1.1

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        divisor = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                char = str1[i]
                modulo1 = len(str1) % (len(divisor) + 1)
                modulo2 = len(str2) % (len(divisor) + 1)
                print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
                if modulo1 == 0 and modulo2 == 0:
                    divisor += char
                    print(f"\t\tInterim divisor length: {len(divisor)}")
                else:
                    print(f"No longer divisor")
                    break
            else:
                print(f"Characters no longer match")
                break
        
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

str1 = "NANANA"
str2 = "NANA"

Output = "NA"
solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: NANANA; String 2: NANA
# 	Index: 0	N	N
# 		Modulus 1: 0	Modulus 2: 0
# 		Interim divisor length: 1
# 	Index: 1	A	A
# 		Modulus 1: 0	Modulus 2: 0
# 		Interim divisor length: 2
# 	Index: 2	N	N
# 		Modulus 1: 0	Modulus 2: 1
# No longer divisor
# divisor: NA (length: 2)
# Answer is correct: True

# %% [markdown]
# ### 1.2 remove print statements

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        min_length = min(len(str1), len(str2))
        divisor = ""
        for i in range(min_length):
            if str1[i] == str2[i]:
                char = str1[i]
                modulo1 = len(str1) % (len(divisor) + 1)
                modulo2 = len(str2) % (len(divisor) + 1)
                if modulo1 == 0 and modulo2 == 0:
                    divisor += char
                else:
                    break
            else:
                break
        return divisor

str1 = "NANANA"
str2 = "NANA"

Output = "NA"
solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# Answer is correct: True

# %% [markdown]
# ## Iteration 2
# * Time: O()
# * Space: O()

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        divisor = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                temp_divisor = divisor + str1[i]
                modulo1 = len(str1) % len(temp_divisor)
                modulo2 = len(str2) % len(temp_divisor)
                print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
                if modulo1 == 0 and modulo2 == 0:
                    multiples1 = int(len(str1) / len(temp_divisor))
                    multiples2 = int(len(str2) / len(temp_divisor))
                    print(f"\t\tMultiples 1: {multiples1}\tMultiples 2: {multiples2}")
                    print(f"\t\tMultiplication 1: {temp_divisor * multiples1}\tMultiplication 2: {temp_divisor * multiples2}")
                    if temp_divisor * multiples1 != str1 or temp_divisor * multiples2 != str2:
                        print(f"No longer divisor")
                        break
                    divisor = temp_divisor
                    print(f"\t\tInterim divisor length: {len(divisor)}")
                else:
                    print(f"No longer divisor")
                    break
            else:
                print(f"Characters no longer match")
                break
        
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

str1 = "NANANA"
str2 = "NANA"
Output = "NA"
solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: NANANA; String 2: NANA
# 	Index: 0	N	N
# 		Modulus 1: 0	Modulus 2: 0
# 		Multiples 1: 6	Multiples 2: 4
# 		Multiplication 1: NNNNNN	Multiplication 2: NNNN
# No longer divisor
# divisor:  (length: 0)
# Answer is correct: False

# %% [markdown]
# ### 2.1 Based on iteration 1.1

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        longest_matching_prefix = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                longest_matching_prefix = longest_matching_prefix + str1[i]
            else:
                print(f"Characters no longer match")
                break
        
        divisor = ""
        temp_divisor = ""
        for j in range(len(longest_matching_prefix)):
            temp_divisor += longest_matching_prefix[j]
            print(f"\tTemp divisor: {temp_divisor}")
            modulo1 = len(str1) % len(temp_divisor)
            modulo2 = len(str2) % len(temp_divisor)
            print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
            if modulo1 == 0 and modulo2 == 0:
                divisor = temp_divisor
            else:
                print(f"No longer divisor")
        
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

str1="ABCABC"
str2="ABC"
Output = "ABC"
solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: ABCABC; String 2: ABC
# 	Index: 0	A	A
# 	Index: 1	B	B
# 	Index: 2	C	C
# 	Temp divisor: A
# 		Modulus 1: 0	Modulus 2: 0
# 	Temp divisor: AB
# 		Modulus 1: 0	Modulus 2: 1
# No longer divisor
# 	Temp divisor: ABC
# 		Modulus 1: 0	Modulus 2: 0
# divisor: ABC (length: 3)
# Answer is correct: True

# %% [markdown]
# ### 2.2

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        longest_matching_prefix = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                longest_matching_prefix = longest_matching_prefix + str1[i]
            else:
                print(f"Characters no longer match")
                break
        
        divisor = ""
        temp_divisor = ""
        for j in range(len(longest_matching_prefix)):
            temp_divisor += longest_matching_prefix[j]
            print(f"\tTemp divisor: {temp_divisor}")
            modulo1 = len(str1) % len(temp_divisor)
            modulo2 = len(str2) % len(temp_divisor)
            print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
            if modulo1 == 0 and modulo2 == 0:
                divisor = temp_divisor
        
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

# str1="ABCABC"
# str2="ABC"
# Output = "ABC"


str1 = "NANANA"
str2 = "NANA"
Output = "NA"

solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: NANANA; String 2: NANA
# 	Index: 0	N	N
# 	Index: 1	A	A
# 	Index: 2	N	N
# 	Index: 3	A	A
# 	Temp divisor: N
# 		Modulus 1: 0	Modulus 2: 0
# 	Temp divisor: NA
# 		Modulus 1: 0	Modulus 2: 0
# 	Temp divisor: NAN
# 		Modulus 1: 0	Modulus 2: 1
# 	Temp divisor: NANA
# 		Modulus 1: 2	Modulus 2: 0
# divisor: NA (length: 2)
# Answer is correct: True

# %% [markdown]
# ## Iteration 3

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        longest_matching_prefix = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                longest_matching_prefix = longest_matching_prefix + str1[i]
            else:
                print(f"Characters no longer match")
                break
        
        divisor = ""
        temp_divisor = ""
        for j in range(len(longest_matching_prefix)):
            temp_divisor += longest_matching_prefix[j]
            print(f"\tTemp divisor: {temp_divisor}")
            modulo1 = len(str1) % len(temp_divisor)
            modulo2 = len(str2) % len(temp_divisor)
            print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
            if modulo1 != 0 and modulo2 != 0:
                continue

            # Check that the entire string is a repeat of the divisor
            multiples1 = int(len(str1) / len(temp_divisor))
            for k in range(multiples1):
                substring1 = str1[k:len(temp_divisor)]
                if substring1 == divisor:
                    divisor = temp_divisor
                else:
                    break
            multiples2 = int(len(str2) / len(temp_divisor))
            for k in range(multiples2):
                substring2 = str2[k:len(temp_divisor)]
                if substring2 == divisor:
                    divisor = temp_divisor
                else:
                    break
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

# str1="ABCABC"
# str2="ABC"
# Output = "ABC"


# str1 = "NANANA"
# str2 = "NANA"
# Output = "NA"

str1="ABCDEF"
str2="ABC"
Output = ""

solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: ABCDEF; String 2: ABC
# 	Index: 0	A	A
# 	Index: 1	B	B
# 	Index: 2	C	C
# 	Temp divisor: A
# 		Modulus 1: 0	Modulus 2: 0
# 	Temp divisor: AB
# 		Modulus 1: 0	Modulus 2: 1
# 	Temp divisor: ABC
# 		Modulus 1: 0	Modulus 2: 0
# divisor:  (length: 0)
# Answer is correct: True

# %% [markdown]
# ### 3.1

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        longest_matching_prefix = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                longest_matching_prefix = longest_matching_prefix + str1[i]
            else:
                print(f"Characters no longer match")
                break
        
        divisor = ""
        temp_divisor = ""
        for j in range(len(longest_matching_prefix)):
            temp_divisor += longest_matching_prefix[j]
            print(f"\tTemp divisor: {temp_divisor}")
            modulo1 = len(str1) % len(temp_divisor)
            modulo2 = len(str2) % len(temp_divisor)
            print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
            if modulo1 != 0 and modulo2 != 0:
                continue

            # Check that the entire string is a repeat of the divisor
            multiples1 = int(len(str1) / len(temp_divisor))
            print(f"\tMultiples1: {multiples1}")
            for k in range(multiples1):
                substring1 = str1[k:len(temp_divisor)]
                substring2 = str1[len(temp_divisor) : len(temp_divisor) * 2]
                if substring1 == substring2 or substring2 == "":
                    divisor = temp_divisor
                else:
                    continue
            multiples2 = int(len(str2) / len(temp_divisor))
            for k in range(multiples2):
                substring1 = str2[k:len(temp_divisor)]
                substring2 = str2[len(temp_divisor) : len(temp_divisor) * 2]
                if substring1 == substring2 or substring2 == "":
                    divisor = temp_divisor
                else:
                    continue
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

str1="ABCABC"
str2="ABC"
Output = "ABC"


# str1 = "NANANA"
# str2 = "NANA"
# Output = "NA"

# str1="ABCDEF"
# str2="ABC"
# Output = ""



str1="A"
str2="A"
Output = "A"

solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: A; String 2: A
# 	Index: 0	A	A
# 	Temp divisor: A
# 		Modulus 1: 0	Modulus 2: 0
# 	Multiples1: 1
# divisor: A (length: 1)
# Answer is correct: True

# %% [markdown]
# ### 3.2

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        longest_matching_prefix = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                longest_matching_prefix = longest_matching_prefix + str1[i]
            else:
                print(f"Characters no longer match")
                break
        
        divisor = ""
        temp_divisor = ""
        for j in range(len(longest_matching_prefix)):
            temp_divisor += longest_matching_prefix[j]
            print(f"\tTemp divisor: {temp_divisor}")
            modulo1 = len(str1) % len(temp_divisor)
            modulo2 = len(str2) % len(temp_divisor)
            print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
            if modulo1 != 0 and modulo2 != 0:
                continue

            # Check that the entire string is a repeat of the divisor
            multiples1 = int(len(str1) / len(temp_divisor))
            print(f"\tMultiples1: {multiples1}")
            if multiples1 == 1 and str1 == temp_divisor:
                divisor = temp_divisor
                continue
            for k in range(multiples1):
                substring1 = str1[k:len(temp_divisor)]
                substring2 = str1[len(temp_divisor) : len(temp_divisor) * 2]
                if substring1 == substring2 :
                    divisor = temp_divisor
                else:
                    continue
            multiples2 = int(len(str2) / len(temp_divisor))
            if multiples2 == 1 and str2 == temp_divisor:
                divisor = temp_divisor
                continue
            for k in range(multiples2):
                substring1 = str2[k:len(temp_divisor)]
                substring2 = str2[len(temp_divisor) : len(temp_divisor) * 2]
                if substring1 == substring2 :
                    divisor = temp_divisor
                else:
                    continue
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

str1="ABCABC"
str2="ABC"
Output = "ABC"


str1 = "NANANA"
str2 = "NANA"
Output = "NA"

# str1="ABCDEF"
# str2="ABC"
# Output = ""



# str1="A"
# str2="A"
# Output = "A"

solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: NANANA; String 2: NANA
# 	Index: 0	N	N
# 	Index: 1	A	A
# 	Index: 2	N	N
# 	Index: 3	A	A
# 	Temp divisor: N
# 		Modulus 1: 0	Modulus 2: 0
# 	Multiples1: 6
# 	Temp divisor: NA
# 		Modulus 1: 0	Modulus 2: 0
# 	Multiples1: 3
# 	Temp divisor: NAN
# 		Modulus 1: 0	Modulus 2: 1
# 	Multiples1: 2
# 	Temp divisor: NANA
# 		Modulus 1: 2	Modulus 2: 0
# 	Multiples1: 1
# divisor: NANA (length: 4)
# Answer is correct: False

# %% [markdown]
# ### 3.3

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        longest_matching_prefix = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                longest_matching_prefix = longest_matching_prefix + str1[i]
            else:
                print(f"Characters no longer match")
                break
        
        divisor = ""
        temp_divisor = ""
        for j in range(len(longest_matching_prefix)):
            temp_divisor += longest_matching_prefix[j]
            print(f"\tTemp divisor: {temp_divisor}")
            modulo1 = len(str1) % len(temp_divisor)
            modulo2 = len(str2) % len(temp_divisor)
            print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
            if modulo1 != 0 and modulo2 != 0:
                continue

            # Check that the entire string is a repeat of the divisor
            multiples1 = int(len(str1) / len(temp_divisor))
            multiples2 = int(len(str2) / len(temp_divisor))
            if multiples1 == 1 and str1 == temp_divisor and multiples2 == 1 and str2 == temp_divisor:
                divisor = temp_divisor
                continue
            for k in range(multiples1):
                substring1 = str1[k:len(temp_divisor)]
                substring2 = str1[len(temp_divisor) : len(temp_divisor) * 2]
                if substring1 == substring2 :
                    divisor = temp_divisor
                else:
                    continue
            for k in range(multiples2):
                substring1 = str2[k:len(temp_divisor)]
                substring2 = str2[len(temp_divisor) : len(temp_divisor) * 2]
                if substring1 == substring2 :
                    divisor = temp_divisor
                else:
                    continue
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

str1="ABCABC"
str2="ABC"
Output = "ABC"


str1 = "NANANA"
str2 = "NANA"
Output = "NA"

# str1="ABCDEF"
# str2="ABC"
# Output = ""



str1="A"
str2="A"
Output = "A"

solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")
# Out:
# String 1: A; String 2: A
# 	Index: 0	A	A
# 	Temp divisor: A
# 		Modulus 1: 0	Modulus 2: 0
# divisor: A (length: 1)
# Answer is correct: True

# %% [markdown]
# ## Iteration 4

# %%
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        print(f"String 1: {str1}; String 2: {str2}")
        min_length = min(len(str1), len(str2))
        longest_matching_prefix = ""
        for i in range(min_length):
            print(f"\tIndex: {i}\t{str1[i]}\t{str2[i]}")
            if str1[i] == str2[i]:
                longest_matching_prefix = longest_matching_prefix + str1[i]
            else:
                print(f"Characters no longer match")
                break
        
        divisor = ""
        temp_divisor = ""
        for j in range(len(longest_matching_prefix)):
            temp_divisor += longest_matching_prefix[j]
            print(f"\tTemp divisor: {temp_divisor}")
            modulo1 = len(str1) % len(temp_divisor)
            modulo2 = len(str2) % len(temp_divisor)
            print(f"\t\tModulus 1: {modulo1}\tModulus 2: {modulo2}")
            if modulo1 != 0 and modulo2 != 0:
                continue

            # Check that the entire string is a repeat of the divisor
            multiples1 = int(len(str1) / len(temp_divisor))
            multiples2 = int(len(str2) / len(temp_divisor))
            if multiples1 == 1 and str1 == temp_divisor and multiples2 == 1 and str2 == temp_divisor:
                divisor = temp_divisor
                continue
            for k in range(multiples1):
                substring1 = str1[k:len(temp_divisor)]
                substring2 = str1[len(temp_divisor) : len(temp_divisor) * 2]
                if substring1 == substring2 :
                    divisor = temp_divisor
                else:
                    continue
            for k in range(multiples2):
                substring1 = str2[k:len(temp_divisor)]
                substring2 = str2[len(temp_divisor) : len(temp_divisor) * 2]
                if substring1 == substring2 :
                    divisor = temp_divisor
                else:
                    continue
        print(f"divisor: {divisor} (length: {len(divisor)})")
        return divisor

str1="ABCABC"
str2="ABC"
Output = "ABC"


str1 = "NANANA"
str2 = "NANA"
Output = "NA"

# str1="ABCDEF"
# str2="ABC"
# Output = ""


str1="A"
str2="A"
Output = "A"

solution = Solution()
result = solution.gcdOfStrings(str1, str2)

print(f"Answer is correct: {result == Output}")

# %% [markdown]
# # *End of Page*
